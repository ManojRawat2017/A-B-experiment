# %% [markdown]
# Objective: Expand NPS Predictive Model based on Flight Control/Treatment pairs to newer datasets and also to more apps than just Excel.

# %%
import math
import pandas as pd
import numpy as np
import datetime
import sklearn.tree
from graphviz import Source
from IPython.display import SVG
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.feature_selection import RFE
import os

from sklearn.linear_model import LogisticRegressionCV, LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb

import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats

def transform_rating(rating):
    '''Input: Column of Data with NPS Field (on a scale of 1 to 5...)
    Output: Column with either Promoter/Detractor/Passive label, or the corresponding weights, based on datatype'''
    
    if rating == 5:
        return 100
    elif rating <= 3:
        return -100
    elif rating == 4:
        return 0
    else:
        return np.nan

# %%
Word_df = pd.read_csv('Word_updated_dataOct.tsv', sep='\t')

# %%
Word_df.head()
# Out:
#                                        OcvId  \
# 0  flnps_v2_dda9bf5625245a989e34b176c130e96c
# 1  flnps_v2_d82877cc43795053a9dd48af73202391
# 2  flnps_v2_6b9d9aeb09665579b885b966ef0383c1
# 3  flnps_v2_86fe37562d1159bea1ead15901571d0c
# 4  flnps_v2_7edad9a9c9155ef7abb8b10f5852926c
#
#                        ProcessSessionId                    Date    LongDate  \
# 0  477f17f3-a06d-4d50-8a33-8d9ca38206f4   10/15/2019 2:40:08 AM  2019-10-15
# 1  481f12ae-04b2-4417-a35f-e2a4a08240de    7/30/2019 2:41:00 AM  2019-07-30
# 2  4fdd7235-92de-4d5f-9e0c-65a65410d534   10/28/2019 1:40:28 AM  2019-10-28
# 3  20aead01-99af-400d-a7ee-50739fa4ddbe   9/23/2019 10:49:34 AM  2019-09-23
# 4  012a8457-ca90-4c2c-a4cc-d96e61f52c1f  10/15/2019 12:16:01 PM  2019-10-15
#
#   Platform Product  Rating  SurveyRatingScale                   OriginalText  \
# 0      Web    Word       5                  5                            NaN
# 1      Web    Word       4                  5              Because i like it
# 2      Web    Word       4                  5                            NaN
# 3      Web    Word       5                  5                            NaN
# 4      Web    Word       5                  5  by having autocorrect please]
#
#                         Verbatim  ...  Skus rn           FlightId  \
# 0                            NaN  ...   NaN  1  canary-docowner-t
# 1              Because i like it  ...   NaN  1           NoFlight
# 2                            NaN  ...   NaN  1  canary-docowner-t
# 3                            NaN  ...   NaN  1  canary-docowner-t
# 4  by having autocorrect please]  ...   NaN  1           NoFlight
#
#                            WacSessionId                          WACSessionID  \
# 0  477f17f3-a06d-4d50-8a33-8d9ca38206f4  477f17f3-a06d-4d50-8a33-8d9ca38206f4
# 1  481f12ae-04b2-4417-a35f-e2a4a08240de  481f12ae-04b2-4417-a35f-e2a4a08240de
# 2  4fdd7235-92de-4d5f-9e0c-65a65410d534  4fdd7235-92de-4d5f-9e0c-65a65410d534
# 3  20aead01-99af-400d-a7ee-50739fa4ddbe  20aead01-99af-400d-a7ee-50739fa4ddbe
# 4  012a8457-ca90-4c2c-a4cc-d96e61f52c1f  012a8457-ca90-4c2c-a4cc-d96e61f52c1f
#
#    Application ApplicationMode ApplicationLCID               Host rn1
# 0         Word         Unified           en-US  SharePoint Online   1
# 1         Word         Unified           en-GB  SharePoint Online   1
# 2         Word         Unified           en-US       OneDriveWOPI   1
# 3         Word         Unified           en-US  SharePoint Online   1
# 4         Word         Unified           en-US  SharePoint Online   1
#
# [5 rows x 39 columns]

# %%
Excel_df = pd.read_csv('Excel_updated_dataOct.tsv', sep='\t')
PP_df = pd.read_csv('PowerPoint_updated_dataOct.tsv', sep='\t')
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
PP_df.head()
# Out:
#                                        OcvId  \
# 0  flnps_v2_b59dd6b09c805661bc7face573961b82
# 1  flnps_v2_b3397471bc1158b9b359291a1da871ab
# 2  flnps_v2_cb448186b6ad52809d8199a77b9772ae
# 3  flnps_v2_6722df959f745987b2718d2ae4b17606
# 4  flnps_v2_5eeca61dece15306ac756297f59dccbe
#
#                        ProcessSessionId                   Date    LongDate  \
# 0  477e30ec-a5ad-4052-af7a-5cbedcc7d96b  10/27/2019 2:04:04 PM  2019-10-27
# 1  481cce98-912d-66ac-366b-81cb3731d61a    6/4/2019 1:34:26 PM  2019-06-04
# 2  4fd742a2-1196-486b-9518-68b8530a1fe4    5/4/2019 8:10:28 PM  2019-05-04
# 3  20aeb498-8576-4915-a6e1-fa4697445d3c   5/31/2019 7:55:06 PM  2019-05-31
# 4  01339fec-c71d-4cd9-a486-22a0c14c5a49    7/1/2019 2:25:29 PM  2019-07-01
#
#   Platform     Product  Rating  SurveyRatingScale  \
# 0      Web  PowerPoint       5                  5
# 1      Web  PowerPoint       3                  5
# 2      Web  PowerPoint       5                  5
# 3      Web  PowerPoint       5                  5
# 4      Web  PowerPoint       3                  5
#
#                                         OriginalText  \
# 0  Facilita a edição, é prático e oferece bons de...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                             Verbatim  ...  Skus rn  \
# 0  Facilitates editing, is practical and offers g...  ...   NaN  1
# 1                                                NaN  ...   NaN  1
# 2                                                NaN  ...   NaN  1
# 3                                                NaN  ...   NaN  1
# 4                                                NaN  ...   NaN  1
#
#                FlightId                          WacSessionId  \
# 0              canary-c  477e30ec-a5ad-4052-af7a-5cbedcc7d96b
# 1              canary-c  481cce98-912d-66ac-366b-81cb3731d61a
# 2              canary-t  4fd742a2-1196-486b-9518-68b8530a1fe4
# 3              canary-t  20aeb498-8576-4915-a6e1-fa4697445d3c
# 4  afd_ignorewaccluster  01339fec-c71d-4cd9-a486-22a0c14c5a49
#
#                            WACSessionID  Application ApplicationMode  \
# 0  477e30ec-a5ad-4052-af7a-5cbedcc7d96b   PowerPoint         Unified
# 1  481cce98-912d-66ac-366b-81cb3731d61a   PowerPoint         Unified
# 2  4fd742a2-1196-486b-9518-68b8530a1fe4   PowerPoint         Unified
# 3  20aeb498-8576-4915-a6e1-fa4697445d3c   PowerPoint         Unified
# 4  01339fec-c71d-4cd9-a486-22a0c14c5a49   PowerPoint         Unified
#
#   ApplicationLCID               Host rn1
# 0           pt-BR       OneDriveWOPI   1
# 1           en-US  SharePoint Online   1
# 2           pt-BR       OneDriveWOPI   1
# 3           en-US  SharePoint Online   1
# 4           en-US       OneDriveWOPI   1
#
# [5 rows x 39 columns]

# %%
def make_AB_dataset(df,prefixes):
    '''df: initial input dataframe of flight data
    prefixes: flights have prefixes - this arg is a list for which prefixes we want to filter on'''
    df = df[df['AudienceGroup']=='Production']
    df['Date'] = pd.to_datetime(df['Date'])
    flights = df.FlightId.astype(str).unique()
    controls = [f for f in flights if f.endswith('-c') or f.__contains__('control')]
    treatments = [f for f in flights if f.endswith('-t') or f.__contains__('treatment')]
    neither = [f for f in flights if (f not in controls) and (f not in treatments)]
    union = {'controls':[c.rstrip('control') for c in controls],'treatments':[t.rstrip('treatments') for t in treatments]}
    no_control = list(set(union['treatments'])-set(union['controls']))
    control_treatment_pairs = list(set(union['treatments'])-set(no_control))
    df['FlightPair']=df['FlightId'].astype(str).map(lambda x: x.rstrip('control'))
    df['FlightPair']=df['FlightPair'].map(lambda x: x.rstrip('treatment'))
    #df['FlightPair'].replace('docowner-canary','canary-docowner',inplace=True)
    
    
    ab_df = df[df.FlightId.notnull()]
    ab_df.drop_duplicates(keep='last', inplace=True)
    print(ab_df.shape, ' before filtering out non-pairs')
    ab_df = ab_df[ab_df['FlightPair'].isin(control_treatment_pairs)]
    print(ab_df.shape, ' after filtering out non-pairs')
    ab_df.loc[ab_df.FlightId.str.endswith('-c'),'Group'] = 'Control'
    ab_df.loc[ab_df.FlightId.str.endswith('control'),'Group'] = 'Control'
    ab_df.loc[ab_df.FlightId.str.endswith('-t'),'Group'] = 'Treatment'
    ab_df.loc[ab_df.FlightId.str.endswith('treatment'),'Group'] = 'Treatment'
    ab_df.loc[ab_df.FlightId.str.endswith('-c'),'Flight'] = 0
    ab_df.loc[ab_df.FlightId.str.endswith('control'),'Flight'] = 0
    ab_df.loc[ab_df.FlightId.str.endswith('-t'),'Flight'] = 1
    ab_df.loc[ab_df.FlightId.str.endswith('treatment'),'Flight'] = 1
    ab_df = ab_df[ab_df.Flight.notnull()]
    ab_df['NPS'] = ab_df['Rating'].apply(transform_rating)
    ab_df = ab_df.sort_values(by='Date')
    value_key = ab_df.sort_values(by='Date').groupby(['OcvId'])['NPS'].last().to_dict()
    exp_df = ab_df.groupby(['OcvId','FlightPair'])['Flight'].last().unstack()
    print('Feature Matrix should have ',ab_df.OcvId.nunique(), ' rows and ',ab_df.FlightPair.nunique(),' columns')
    print('Final Shape:',exp_df.shape)
    if prefixes: #i.e. if the input list is empty:
        for p in prefixes:
            exp_df = exp_df.iloc[:,exp_df.columns.str.startswith(p)]
    exp_df['NPS'] = exp_df.index.map(value_key)
    return exp_df.fillna(0)

#excel_df = make_AB_dataset(Excel_df,['xls'])

# %%
####### JUST READ THE CSV IF YOUVE RAN ALREADY #######

def get_flight_durations():
    ''' no inputs/arguments, just make sure you have all of the Tabular Flight data files you are using.'''
    df = pd.concat([Excel_df[Excel_df['AudienceGroup']=='Production'][Excel_df.FlightId.notnull()],
                    Word_df[Word_df['AudienceGroup']=='Production'][Word_df.FlightId.notnull()],
                    PP_df[PP_df['AudienceGroup']=='Production'][PP_df.FlightId.notnull()]])
    #df = df[df['AudienceGroup']=='Production']
    df['Date'] = pd.to_datetime(df['Date'])
    flights = df.FlightId.astype(str).unique()
    controls = [f for f in flights if f.endswith('-c') or f.__contains__('control')]
    treatments = [f for f in flights if f.endswith('-t') or f.__contains__('treatment')]
    neither = [f for f in flights if (f not in controls) and (f not in treatments)]
    union = {'controls':[c.rstrip('control') for c in controls],'treatments':[t.rstrip('treatments') for t in treatments]}
    no_control = list(set(union['treatments'])-set(union['controls']))
    control_treatment_pairs = list(set(union['treatments'])-set(no_control))
    df['FlightPair']=df['FlightId'].astype(str).map(lambda x: x.rstrip('control'))
    df['FlightPair']=df['FlightPair'].map(lambda x: x.rstrip('treatment'))
    
    print('Flight Pairs Assigned')
    
    ab_df = df[df.FlightPair.notnull()]
    #ab_df.drop_duplicates(keep='last', inplace=True)
    ab_df = ab_df[ab_df['FlightPair'].isin(control_treatment_pairs)]
    flight_starts = ab_df.sort_values(by='Date').groupby(['FlightPair'])['Date'].first()
    flight_ends = ab_df.sort_values(by='Date').groupby(['FlightPair'])['Date'].last()
    flight_durations = pd.concat([flight_starts,flight_ends],axis=1)
    flight_durations.columns = ['FlightStart','FlightEnd']
    return flight_durations
    
flight_durations = get_flight_durations()
# Out:
# Flight Pairs Assigned

# %%
flight_durations.to_csv('FlightsOctober.csv')

# %%
excel_df = make_AB_dataset(Excel_df,[])
word_df = make_AB_dataset(Word_df,[])
pp_df = make_AB_dataset(PP_df,[])
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (875085, 40)  before filtering out non-pairs
# (625273, 40)  after filtering out non-pairs
# Feature Matrix should have  23319  rows and  145  columns
# Final Shape: (23319, 145)
# (1497298, 40)  before filtering out non-pairs
# (1075637, 40)  after filtering out non-pairs
# Feature Matrix should have  25139  rows and  240  columns
# Final Shape: (25139, 240)
# (428103, 40)  before filtering out non-pairs
# (242723, 40)  after filtering out non-pairs
# Feature Matrix should have  18610  rows and  62  columns
# Final Shape: (18610, 62)

# %%
excel_flights = list(excel_df.columns)
word_flights = list(word_df.columns)
common_flights = list(set(excel_flights).intersection(word_flights))
pp_flights = list(pp_df.columns)
common_flights = list(set(common_flights).intersection(pp_flights))

# %%
common_flights.remove('NPS')

# %%
common_flights
# Out:
# ['canary-',
#  'wac-wordimagegroupcontainerfittopage-',
#  'wac-box4secureuuid-',
#  'wacdash-',
#  'wac-wordclearformattingtrackchanges-',
#  'wac-owaunifiedapp-',
#  'wac-wordcloneatmentionpropertiesinhyperlink-',
#  'wac-wordwordoauthtestappaadtokenretrieval-',
#  'wac-mergemissingeopfix-',
#  'wac-licensingisenabled-',
#  'wac-worduseaadforfileupload-',
#  'wac-wordeditorcashdashisactivecoauth-',
#  'docowneridtestaa-',
#  'xls-customsortforallrangetypes-',
#  'xls-removescrolltofirstandlastsheettabnavbuttons-',
#  'wac-wordsdxpreloadpackagelist-',
#  'wac-minimizeintelligentplaceholderwork-',
#  'xls-overridebrowsershortcuts-',
#  'wac-wordpreserveverbonredirect-',
#  'wac-worddefinenewbullettablecellclassname-',
#  'docowner-canary-',
#  'wac-oauthtestappmsatokenretrieval-',
#  'firstrelease-',
#  'wac-box4directprinthidesensitiveparameters-',
#  'wac-oauthmsatokenretrieval-',
#  'canary-user-',
#  'wac-worduseoauthfullyfordlp-',
#  'canary-docowner-',
#  'canary2-',
#  'wac-worddeprioritizerichtextcontentcontrolacetateforcoauth-',
#  'useridtestaa-',
#  'wac-wordshowpasteoptionsincontextmenu-',
#  'wac-ocpsisenabled-',
#  'wac-wordkeepmaxlastknownheight-',
#  'wac-wordwordoauthtestappmsatokenretrieval-']

# %%
dc = ['docowner-canary-','canary-docowner-',
     'canary2','canary-']

# %%
X = {'excel':excel_df.iloc[:,excel_df.columns.str.startswith('xls')],
     'word':word_df.iloc[:,word_df.columns.str.startswith('wac')],
     'pp':pp_df.iloc[:,pp_df.columns.str.startswith('pp')],
     'all':pd.concat([excel_df,word_df,pp_df]).loc[:,common_flights]}
y = {'excel':excel_df['NPS'].replace([100,0],1).replace(-100,0)
     ,'word':word_df['NPS'].replace([100,0],1).replace(-100,0),
     'pp':pp_df['NPS'].replace([100,0],1).replace(-100,0),
     'all':pd.concat([excel_df,word_df,pp_df])['NPS'].replace([100,0],1).replace(-100,0)}
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
print(X['excel'].shape, y['excel'].shape)
print(X['word'].shape, y['word'].shape)
print(X['pp'].shape, y['pp'].shape)
print(X['all'].shape, y['all'].shape)
# Out:
# (23319, 104) (23319,)
# (25139, 220) (25139,)
# (18610, 18) (18610,)
# (67068, 35) (67068,)

# %%
model_perfs = pd.DataFrame(columns=['Logistic','RandomForest','GradientBoosting'])
for key in ['excel','word','pp','all']:
########## WHEN PREDICTORS ARE BINARY (1 for Treatment, 0 otherwise) ###############
    logit = LogisticRegression().fit(X[key],y[key])
    rf = RandomForestClassifier(random_state=0).fit(X[key],y[key])
    gb = xgb.XGBClassifier(random_state=0, n_jobs=4).fit(X[key],y[key])
    
    log_acc = round(logit.score(X[key],y[key]),3)
    rf_acc = round(rf.score(X[key],y[key]),3)
    gb_acc = round(gb.score(X[key],y[key]),3)

    model_perfs.loc[key+'Accuracy']=[log_acc,rf_acc,gb_acc]
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
model_perfs
# Out:
#                Logistic  RandomForest  GradientBoosting
# excelAccuracy     0.724         0.839             0.725
# wordAccuracy      0.716         0.966             0.716
# ppAccuracy        0.755         0.756             0.755
# allAccuracy       0.730         0.756             0.730

# %% [markdown]
# ## Excel

# %%
X_train, X_test, y_train, y_test = train_test_split(X['excel'], y['excel'], test_size=0.2)

# %%
### ONLY RUN IF THERE IS NO OUTPUT ###
rf = RandomForestClassifier(random_state=0)
param_grid = { 
    'n_estimators': [50, 100, 250, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [2,5,10,None],
    'oob_score': [True,False]}

CV_rfc = GridSearchCV(estimator=rf, n_jobs=-1, param_grid=param_grid, verbose=10, scoring='neg_log_loss',cv= 5)
CV_rfc.fit(X_train, y_train)
print(CV_rfc.best_params_, CV_rfc.best_score_)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   41.6s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   52.0s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:   55.8s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done 480 out of 480 | elapsed: 16.9min finished
# {'max_depth': 5, 'max_features': 'auto', 'n_estimators': 100, 'oob_score': True} -0.5730808817257358

# %%
print(RandomForestClassifier(random_state=0).fit(X_train,
                                           y_train).score(X_test,y_test))


rfc = RandomForestClassifier(random_state = 0, n_estimators = 100,
                      max_depth=5,oob_score=True)
rfc.fit(X_train,y_train)
print(rfc.score(X_test,y_test))

learners = rfc.feature_importances_.argsort()[::-1]

features = pd.DataFrame(X_train.columns[learners], rfc.feature_importances_[learners])
features = features[features.index>0.01]
features
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.6775300171526587
# 0.7244854202401372
#                                                FlightPair
# 0.063438                               xls-ocpsisenabled-
# 0.053517                                         xls-wac-
# 0.052797                          xls-licensingisenabled-
# 0.050381                   xls-tabletextcontrastacccheck-
# 0.048666                     xls-keyboardshortcutsdialog-
# 0.046095          xls-chartfloatingobjectcontrolfallback-
# 0.045815                              xls-mergedecoupled-
# 0.040933        xls-newcopypasteexperienceacrosssessions-
# 0.033053           xls-usezonereallocforclonesaveenabled-
# 0.029782                  xls-namedsheetviewspassivetest-
# 0.024785                           xls-slrcachegalleries-
# 0.024028                      xls-modernpresencecanvasux-
# 0.021554                      xls-newcommentbuttoninpane-
# 0.020090                                       xls-ideas-
# 0.020022                       xls-xlowatermarkroundtrip-
# 0.019893                      xls-helptabwhatsnewenabled-
# 0.018812                       xls-slrcachecomboboxmenus-
# 0.017765                      xls-cardviewshowricherrors-
# 0.016909                      xls-freemiumupsellheaderui-
# 0.014277           xls-newcopypasteexperienceenhancement-
# 0.013127                xls-satoriforthirdpartiesenabled-
# 0.012980                  xls-canvasclientsideestimation-
# 0.012220                              xls-converttorange-
# 0.011357                               xls-adaptivecards-
# 0.011175                            xls-ivye2oscenegraph-
# 0.011005                    xls-overridebrowsershortcuts-
# 0.010782                           xls-singlethreadedmtr-
# 0.010227  xls-ecsocsmocsitimeoutraisesirrecoverableerror-

# %%
print(LogisticRegression().fit(X_train,y_train).score(X_test,y_test), ' -->...')

for i in [1,2,3,4,5,10,15,20,25,50,75,100]:
    print('Score with Top ',i,' Features:')
    logit = LogisticRegression(solver='liblinear')

    rfe = RFE(logit,i)
    rfe = rfe.fit(X_train,y_train.values.ravel())

    rfe.support_
    rfe.ranking_

    #identified columns Recursive Feature Elimination
    idc_rfe = pd.DataFrame({"rfe_support" :rfe.support_,
                           "columns" : [i for i in X_train.columns],
                           "ranking" : rfe.ranking_,
                          })
    cols = idc_rfe[idc_rfe["rfe_support"] == True]["columns"].tolist()


    #separating train and test data
    train_rfe_X = X_train[cols]
    train_rfe_y = y_train.copy()

    test_rfe_X = X_test[cols]
    test_rfe_y = y_test.copy()


    logit_rfe = LogisticRegression(class_weight=None, dual=False, fit_intercept=True,
              intercept_scaling=1, max_iter=100, #n_jobs=4,
              penalty='l2', random_state=None, solver='liblinear', #tol=0.0001,
              verbose=0, warm_start=False)

    logit_rfe.fit(train_rfe_X, train_rfe_y)
    print(logit_rfe.score(test_rfe_X,test_rfe_y))
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.714622641509434  -->...
# Score with Top  1  Features:
# 0.7152658662092625
# Score with Top  2  Features:
# 0.7152658662092625
# Score with Top  3  Features:
# 0.7152658662092625
# Score with Top  4  Features:
# 0.7152658662092625
# Score with Top  5  Features:
# 0.7152658662092625
# Score with Top  10  Features:
# 0.7152658662092625
# Score with Top  15  Features:
# 0.7152658662092625
# Score with Top  20  Features:
# 0.7152658662092625
# Score with Top  25  Features:
# 0.7152658662092625
# Score with Top  50  Features:
# 0.714622641509434
# Score with Top  75  Features:
# 0.714622641509434
# Score with Top  100  Features:
# 0.714622641509434

# %%
print(logit.fit(X_train,y_train).score(X_test,y_test), ' -->...')
logit_rfe.score(test_rfe_X,test_rfe_y)

# %%
logit = LogisticRegression(solver='liblinear')

rfe = RFE(logit,25)
rfe = rfe.fit(X_train,y_train.values.ravel())

rfe.ranking_

#identified columns Recursive Feature Elimination
idc_rfe = pd.DataFrame({"rfe_support" :rfe.support_,
                       "columns" : [i for i in X_train.columns],
                       "ranking" : rfe.ranking_,
                      })

cols = idc_rfe[idc_rfe["rfe_support"] == True]["columns"].tolist()

# %%
cols.extend(features.FlightPair.values.tolist())
cols = list(set(cols))

logit = sm.Logit(y['excel'],X['excel'].loc[:,cols])
flogit = logit.fit()
print(flogit.summary())

coefficients = flogit.summary2().tables[1]
coefficients = coefficients[coefficients['P>|z|']<0.1]
coefficients['Odds Ratio']=np.exp(coefficients['Coef.'])
coefficients['O.R.LB']=np.exp(coefficients['[0.025'])
coefficients['O.R.UB']=np.exp(coefficients['0.975]'])
coefficients.join(flight_durations)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.583730
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    NPS   No. Observations:                23319
# Model:                          Logit   Df Residuals:                    23287
# Method:                           MLE   Df Model:                           31
# Date:                Tue, 12 Nov 2019   Pseudo R-squ.:                0.008407
# Time:                        16:58:27   Log-Likelihood:                -13612.
# converged:                      False   LL-Null:                       -13727.
#                                         LLR p-value:                 2.077e-32
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# xls-insertdatetimeshortcuts-                       14.7122   1507.978      0.010      0.992   -2940.871    2970.295
# xls-chartfloatingobjectcontrolfallback-             0.0639      0.110      0.582      0.561      -0.151       0.279
# xls-modernpresencecanvasux-                         0.1217      0.109      1.114      0.265      -0.092       0.336
# xls-freemiumupsellheaderui-                         0.3826      0.093      4.120      0.000       0.201       0.565
# xls-mergedecoupled-                                -0.0753      0.108     -0.697      0.486      -0.287       0.136
# xls-ocpsisenabled-                                 -0.3162      0.159     -1.986      0.047      -0.628      -0.004
# xls-calcwebworkersmoketest-                        -0.4296      0.824     -0.521      0.602      -2.045       1.186
# xls-tabletextcontrastacccheck-                      0.3624      0.070      5.188      0.000       0.225       0.499
# xls-licensingisenabled-                            -0.0529   1.41e+07  -3.76e-09      1.000   -2.76e+07    2.76e+07
# xls-gridcanvasrendering-                           22.3498   4.72e+04      0.000      1.000   -9.26e+04    9.26e+04
# xls-usezonereallocforclonesaveenabled-             -0.0699      0.110     -0.633      0.527      -0.286       0.146
# xls-slrcachecomboboxmenus-                          0.4639      0.058      7.931      0.000       0.349       0.579
# xls-newcopypasteexperienceacrosssessions-           0.1049      0.098      1.072      0.284      -0.087       0.297
# xls-newcommentbuttoninpane-                        -0.0727      0.069     -1.050      0.294      -0.208       0.063
# xls-newcopypasteexperienceenhancement-             -0.2441      0.098     -2.490      0.013      -0.436      -0.052
# xls-overridebrowsershortcuts-                      -0.0904      0.079     -1.149      0.251      -0.245       0.064
# xls-satoriforthirdpartiesenabled-                   0.3320      0.108      3.062      0.002       0.120       0.544
# xls-singlethreadedmtr-                             -0.0042      0.056     -0.075      0.940      -0.113       0.105
# xls-converttorange-                                -0.0997      0.100     -1.001      0.317      -0.295       0.096
# xls-xlowatermarkroundtrip-                          0.0728      0.067      1.095      0.274      -0.058       0.203
# xls-namedsheetviewspassivetest-                     0.2528      0.049      5.187      0.000       0.157       0.348
# xls-wac-                                           -0.0529   1.41e+07  -3.76e-09      1.000   -2.76e+07    2.76e+07
# xls-keyboardshortcutsdialog-                        0.5961      0.187      3.192      0.001       0.230       0.962
# xls-helptabwhatsnewenabled-                         0.0390      0.103      0.379      0.705      -0.163       0.241
# xls-earlysessionstartforview-                      -0.1563      0.166     -0.944      0.345      -0.481       0.168
# xls-adaptivecards-                                 -0.0329      0.053     -0.626      0.531      -0.136       0.070
# xls-slrcachegalleries-                              0.3967      0.060      6.598      0.000       0.279       0.515
# xls-ecsocsmocsitimeoutraisesirrecoverableerror-     0.2542      0.059      4.281      0.000       0.138       0.371
# xls-canvasclientsideestimation-                     0.0327      0.048      0.680      0.496      -0.062       0.127
# xls-ivye2oscenegraph-                              -0.0234      0.135     -0.173      0.862      -0.288       0.241
# xls-cardviewshowricherrors-                        -0.0545      0.082     -0.665      0.506      -0.215       0.106
# xls-ideas-                                         -0.0562      0.050     -1.125      0.260      -0.154       0.042
# xls-reconnectsessiononuserinteration-              -0.6900      0.211     -3.268      0.001      -1.104      -0.276
# ===================================================================================================================
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                                                     Coef.  Std.Err.         z  \
# xls-freemiumupsellheaderui-                      0.382579  0.092857  4.120093
# xls-ocpsisenabled-                              -0.316234  0.159234 -1.985976
# xls-tabletextcontrastacccheck-                   0.362393  0.069857  5.187636
# xls-slrcachecomboboxmenus-                       0.463871  0.058488  7.931003
# xls-newcopypasteexperienceenhancement-          -0.244123  0.098050 -2.489769
# xls-satoriforthirdpartiesenabled-                0.331966  0.108398  3.062466
# xls-namedsheetviewspassivetest-                  0.252846  0.048748  5.186802
# xls-keyboardshortcutsdialog-                     0.596113  0.186726  3.192451
# xls-slrcachegalleries-                           0.396684  0.060121  6.598098
# xls-ecsocsmocsitimeoutraisesirrecoverableerror-  0.254157  0.059363  4.281404
# xls-reconnectsessiononuserinteration-           -0.689989  0.211117 -3.268279
#
#                                                         P>|z|    [0.025  \
# xls-freemiumupsellheaderui-                      3.787201e-05  0.200583
# xls-ocpsisenabled-                               4.703600e-02 -0.628327
# xls-tabletextcontrastacccheck-                   2.129807e-07  0.225476
# xls-slrcachecomboboxmenus-                       2.173838e-15  0.349236
# xls-newcopypasteexperienceenhancement-           1.278262e-02 -0.436298
# xls-satoriforthirdpartiesenabled-                2.195214e-03  0.119509
# xls-namedsheetviewspassivetest-                  2.139363e-07  0.157302
# xls-keyboardshortcutsdialog-                     1.410709e-03  0.230137
# xls-slrcachegalleries-                           4.164648e-11  0.278849
# xls-ecsocsmocsitimeoutraisesirrecoverableerror-  1.857176e-05  0.137808
# xls-reconnectsessiononuserinteration-            1.082035e-03 -1.103771
#
#                                                    0.975]  Odds Ratio  \
# xls-freemiumupsellheaderui-                      0.564575    1.466061
# xls-ocpsisenabled-                              -0.004142    0.728889
# xls-tabletextcontrastacccheck-                   0.499311    1.436764
# xls-slrcachecomboboxmenus-                       0.578507    1.590218
# xls-newcopypasteexperienceenhancement-          -0.051948    0.783392
# xls-satoriforthirdpartiesenabled-                0.544423    1.393705
# xls-namedsheetviewspassivetest-                  0.348390    1.287685
# xls-keyboardshortcutsdialog-                     0.962089    1.815051
# xls-slrcachegalleries-                           0.514520    1.486887
# xls-ecsocsmocsitimeoutraisesirrecoverableerror-  0.370506    1.289374
# xls-reconnectsessiononuserinteration-           -0.276208    0.501582
#
#                                                    O.R.LB    O.R.UB  \
# xls-freemiumupsellheaderui-                      1.222115  1.758701
# xls-ocpsisenabled-                               0.533484  0.995867
# xls-tabletextcontrastacccheck-                   1.252919  1.647585
# xls-slrcachecomboboxmenus-                       1.417984  1.783373
# xls-newcopypasteexperienceenhancement-           0.646425  0.949379
# xls-satoriforthirdpartiesenabled-                1.126944  1.723613
# xls-namedsheetviewspassivetest-                  1.170349  1.416785
# xls-keyboardshortcutsdialog-                     1.258773  2.617159
# xls-slrcachegalleries-                           1.321608  1.672835
# xls-ecsocsmocsitimeoutraisesirrecoverableerror-  1.147755  1.448468
# xls-reconnectsessiononuserinteration-            0.331618  0.758655
#
#                                                         FlightStart  \
# xls-freemiumupsellheaderui-                     2019-05-01 01:34:07
# xls-ocpsisenabled-                              2019-10-07 19:09:17
# xls-tabletextcontrastacccheck-                  2019-05-01 02:10:10
# xls-slrcachecomboboxmenus-                      2019-05-01 16:00:05
# xls-newcopypasteexperienceenhancement-          2019-06-24 18:59:14
# xls-satoriforthirdpartiesenabled-               2019-05-01 02:20:05
# xls-namedsheetviewspassivetest-                 2019-05-02 14:35:04
# xls-keyboardshortcutsdialog-                    2019-08-12 13:29:08
# xls-slrcachegalleries-                          2019-05-31 18:09:09
# xls-ecsocsmocsitimeoutraisesirrecoverableerror- 2019-07-02 06:54:59
# xls-reconnectsessiononuserinteration-           2019-08-04 12:29:06
#
#                                                           FlightEnd
# xls-freemiumupsellheaderui-                     2019-10-30 23:05:07
# xls-ocpsisenabled-                              2019-10-30 23:40:17
# xls-tabletextcontrastacccheck-                  2019-07-15 18:10:07
# xls-slrcachecomboboxmenus-                      2019-10-30 23:40:17
# xls-newcopypasteexperienceenhancement-          2019-10-30 23:40:17
# xls-satoriforthirdpartiesenabled-               2019-08-20 12:40:10
# xls-namedsheetviewspassivetest-                 2019-10-28 14:20:18
# xls-keyboardshortcutsdialog-                    2019-10-30 23:40:17
# xls-slrcachegalleries-                          2019-10-30 23:40:17
# xls-ecsocsmocsitimeoutraisesirrecoverableerror- 2019-08-12 15:19:05
# xls-reconnectsessiononuserinteration-           2019-08-15 10:15:38

# %% [markdown]
# ## Word

# %%
X_train, X_test, y_train, y_test = train_test_split(X['word'], y['word'], test_size=0.2)

# %%
rf = RandomForestClassifier(random_state=0)
param_grid = { 
    'n_estimators': [50, 100, 250, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [2,5,10,None],
    'oob_score': [True,False]}

CV_rfc = GridSearchCV(estimator=rf, n_jobs=-1, param_grid=param_grid, verbose=10, scoring='neg_log_loss',cv= 5)
CV_rfc.fit(X_train, y_train)
print(CV_rfc.best_params_, CV_rfc.best_score_)

# %%
CV_rfc

# %%
print(RandomForestClassifier(random_state=0).fit(X_train,
                                           y_train).score(X_test,y_test))
rfc = RandomForestClassifier(random_state = 0, n_estimators = 100,
                      max_depth=5,oob_score=True)

rfc.fit(X_train,y_train)
rfc.score(X_test,y_test)
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.6666666666666666
# 0.7175815433571997

# %%
learners = rfc.feature_importances_.argsort()[::-1]
features = pd.DataFrame(X_train.columns[learners], rfc.feature_importances_[learners])
features = features[features.index>0.01]
features
# Out:
#                                                  FlightPair
# 0.054956                         wac-wordaugloopoperations-
# 0.046067     wac-box4augloopnodeeventsfiringinterval-500ms-
# 0.044586                    wac-wordkeepmaxlastknownheight-
# 0.041598                        wac-box4augloopannotations-
# 0.039503                                 wac-ocpsisenabled-
# 0.031815              wac-wordeditorcashdashisactivecoauth-
# 0.030587                           wac-wordstatefulaugloop-
# 0.029935               wac-wordreacttaskpaneinfrastructure-
# 0.026782               wac-box4augloopannotationsattaching-
# 0.026383                            wac-licensingisenabled-
# 0.026371                  wac-wordaugloopserversideseeding-
# 0.022343                   wac-wordaugloopproprietarytoken-
# 0.022165  wac-wordmixedjustificationparagraphmultiselect...
# 0.020834                wac-box4augloopseedingzerosequence-
# 0.017957              wac-wordeditorhelptabwhatsnewenabled-
# 0.017719    wac-wordeditormergeoutlinegroupnodepropertyfix-
# 0.015969            wac-wordupdatecommanduiperfimprovement-
# 0.015663                      wac-wordreacttaskpanewithmlr-
# 0.015558          wac-wordimproveboldexperienceonmacchrome-
# 0.013376              wac-imagenodecomplexmergepropertyfix-
# 0.012905       wac-wordhandlemixedlistparagraphmultiselect-
# 0.012701                    wac-wordtablesautocontrasttext-
# 0.010734                      wac-wordslrcachecolorpickers-

# %%
print(LogisticRegression().fit(X_train,y_train).score(X_test,y_test), ' -->...')

for i in [1,2,3,4,5,10,15,20,25,50,75,100]:
    print('Score with Top ',i,' Features:')
    logit = LogisticRegression(solver='liblinear')

    rfe = RFE(logit,i)
    rfe = rfe.fit(X_train,y_train.values.ravel())

    rfe.support_
    rfe.ranking_

    #identified columns Recursive Feature Elimination
    idc_rfe = pd.DataFrame({"rfe_support" :rfe.support_,
                           "columns" : [i for i in X_train.columns],
                           "ranking" : rfe.ranking_,
                          })
    cols = idc_rfe[idc_rfe["rfe_support"] == True]["columns"].tolist()


    #separating train and test data
    train_rfe_X = X_train[cols]
    train_rfe_y = y_train.copy()

    test_rfe_X = X_test[cols]
    test_rfe_y = y_test.copy()


    logit_rfe = LogisticRegression(class_weight=None, dual=False, fit_intercept=True,
              intercept_scaling=1, max_iter=100, #n_jobs=4,
              penalty='l2', random_state=None, solver='liblinear', #tol=0.0001,
              verbose=0, warm_start=False)

    logit_rfe.fit(train_rfe_X, train_rfe_y)
    print(logit_rfe.score(test_rfe_X,test_rfe_y))
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.7151949085123309  -->...
# Score with Top  1  Features:
# 0.7175815433571997
# Score with Top  2  Features:
# 0.7175815433571997
# Score with Top  3  Features:
# 0.7175815433571997
# Score with Top  4  Features:
# 0.7175815433571997
# Score with Top  5  Features:
# 0.7175815433571997
# Score with Top  10  Features:
# 0.7175815433571997
# Score with Top  15  Features:
# 0.7175815433571997
# Score with Top  20  Features:
# 0.7175815433571997
# Score with Top  25  Features:
# 0.7175815433571997
# Score with Top  50  Features:
# 0.7167859984089101
# Score with Top  75  Features:
# 0.7165871121718377
# Score with Top  100  Features:
# 0.7165871121718377

# %%
logit = LogisticRegression(solver='liblinear')

rfe = RFE(logit,25)
rfe = rfe.fit(X_train,y_train.values.ravel())

rfe.ranking_

#identified columns Recursive Feature Elimination
idc_rfe = pd.DataFrame({"rfe_support" :rfe.support_,
                       "columns" : [i for i in X_train.columns],
                       "ranking" : rfe.ranking_,
                      })

# %%
cols = idc_rfe[idc_rfe["rfe_support"] == True]["columns"].tolist()

# %%
cols.extend(features.FlightPair.values.tolist())

# %%
cols
# Out:
# ['wac-box4augloopnodeeventsfiringinterval-500ms-',
#  'wac-wordcontextextractionrollout-',
#  'wac-worddeletefrominputevent-',
#  'wac-worddeprioritizerichtextcontentcontrolacetateforcoauth-',
#  'wac-worddownloadcollabfeaturesearlier-',
#  'wac-wordeditoratmentionsbookmarkendfix-',
#  'wac-wordeditorfirstrunexperiencedatastore-',
#  'wac-wordeditorhelptabwhatsnewenabled-',
#  'wac-wordeditorserviceverificationloopab-',
#  'wac-wordfindsessiononboot-',
#  'wac-wordideas-',
#  'wac-wordimagegroupcontainerfittopage-',
#  'wac-wordkeepmaxlastknownheight-',
#  'wac-wordlanguageintelligentsuggestion-',
#  'wac-wordlogtasksdetailsfromcpumeter-',
#  'wac-wordmergedparagraphwordidmappingimprovements-',
#  'wac-wordmergestyletoggleproperties-',
#  'wac-wordmixedjustificationparagraphmultiselectjustify-',
#  'wac-wordnumberedlistindentation-',
#  'wac-wordreactformatpicturetaskpane-',
#  'wac-wordstatefulaugloop-',
#  'wac-wordupdatedcontextualtabvisuals-',
#  'wac-wordupdatedtellmeplaceholder-',
#  'wac-wordversionhistoryreactpdf-',
#  'wac-wordviewerwordviewerusefallbackxmlloader-',
#  'wac-wordaugloopoperations-',
#  'wac-box4augloopnodeeventsfiringinterval-500ms-',
#  'wac-wordkeepmaxlastknownheight-',
#  'wac-box4augloopannotations-',
#  'wac-ocpsisenabled-',
#  'wac-wordeditorcashdashisactivecoauth-',
#  'wac-wordstatefulaugloop-',
#  'wac-wordreacttaskpaneinfrastructure-',
#  'wac-box4augloopannotationsattaching-',
#  'wac-licensingisenabled-',
#  'wac-wordaugloopserversideseeding-',
#  'wac-wordaugloopproprietarytoken-',
#  'wac-wordmixedjustificationparagraphmultiselectjustify-',
#  'wac-box4augloopseedingzerosequence-',
#  'wac-wordeditorhelptabwhatsnewenabled-',
#  'wac-wordeditormergeoutlinegroupnodepropertyfix-',
#  'wac-wordupdatecommanduiperfimprovement-',
#  'wac-wordreacttaskpanewithmlr-',
#  'wac-wordimproveboldexperienceonmacchrome-',
#  'wac-imagenodecomplexmergepropertyfix-',
#  'wac-wordhandlemixedlistparagraphmultiselect-',
#  'wac-wordtablesautocontrasttext-',
#  'wac-wordslrcachecolorpickers-']

# %%
cols = list(set(cols))

logit = sm.Logit(y['word'],X['word'].loc[:,cols])
flogit = logit.fit()
print(flogit.summary())
coefficients = flogit.summary2().tables[1]
coefficients = coefficients[coefficients['P>|z|']<0.1]
coefficients['Odds Ratio']=np.exp(coefficients['Coef.'])
coefficients['O.R.LB']=np.exp(coefficients['[0.025'])
coefficients['O.R.UB']=np.exp(coefficients['0.975]'])
coefficients.join(flight_durations)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.597685
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    NPS   No. Observations:                25139
# Model:                          Logit   Df Residuals:                    25100
# Method:                           MLE   Df Model:                           38
# Date:                Tue, 12 Nov 2019   Pseudo R-squ.:              -0.0008320
# Time:                        17:21:18   Log-Likelihood:                -15025.
# converged:                       True   LL-Null:                       -15013.
#                                         LLR p-value:                     1.000
# ===============================================================================================================================
#                                                                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------
# wac-imagenodecomplexmergepropertyfix-                          -0.0928      0.085     -1.094      0.274      -0.259       0.073
# wac-wordmixedjustificationparagraphmultiselectjustify-          0.5835      0.180      3.239      0.001       0.230       0.937
# wac-worddeprioritizerichtextcontentcontrolacetateforcoauth
# wac-wordmergedparagraphwordidmappingimprovements-               1.0193      0.131      7.809      0.000       0.764       1.275
# wac-wordnumberedlistindentation-                                0.0008      0.156      0.005      0.996      -0.305       0.307
# wac-licensingisenabled-                                         0.2214      0.094      2.347      0.019       0.037       0.406
# wac-wordfindsessiononboot-                                     -0.4267        nan        nan        nan         nan         nan
# wac-wordviewerwordviewerusefallbackxmlloader-                   0.1688      0.232      0.728      0.467      -0.286       0.623
# wac-wordreacttaskpaneinfrastructure-                            0.0324      0.099      0.326      0.744      -0.162       0.227
# ===============================================================================================================================
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:1092: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#                                                        Coef.  Std.Err.  \
# wac-wordmixedjustificationparagraphmultiselectj...  0.583527  0.180165
# wac-worddeprioritizerichtextcontentcontrolaceta... -0.307274  0.131610
# wac-wordreacttaskpanewithmlr-                       0.229835  0.107599
# wac-wordeditorfirstrunexperiencedatastore-         -0.193900  0.088409
# wac-wordideas-                                      0.258515  0.025913
# wac-wordlogtasksdetailsfromcpumeter-                0.589670  0.194377
# wac-wordimagegroupcontainerfittopage-               0.505112  0.121122
# wac-wordeditoratmentionsbookmarkendfix-             0.367735  0.112612
# wac-wordeditorcashdashisactivecoauth-               0.169727  0.062664
# wac-wordversionhistoryreactpdf-                    -0.395999  0.119888
# wac-wordimproveboldexperienceonmacchrome-          -0.445432  0.120547
# wac-wordslrcachecolorpickers-                       0.559680  0.036678
# wac-wordlanguageintelligentsuggestion-              0.245081  0.081632
# wac-wordupdatecommanduiperfimprovement-             0.760794  0.030335
# wac-wordmergedparagraphwordidmappingimprovements-   1.019345  0.130534
# wac-licensingisenabled-                             0.221409  0.094338
#
#                                                             z          P>|z|  \
# wac-wordmixedjustificationparagraphmultiselectj...   3.238850   1.200128e-03
# wac-worddeprioritizerichtextcontentcontrolaceta...  -2.334725   1.955777e-02
# wac-wordreacttaskpanewithmlr-                        2.136042   3.267598e-02
# wac-wordeditorfirstrunexperiencedatastore-          -2.193216   2.829181e-02
# wac-wordideas-                                       9.976362   1.934286e-23
# wac-wordlogtasksdetailsfromcpumeter-                 3.033633   2.416281e-03
# wac-wordimagegroupcontainerfittopage-                4.170276   3.042311e-05
# wac-wordeditoratmentionsbookmarkendfix-              3.265517   1.092643e-03
# wac-wordeditorcashdashisactivecoauth-                2.708538   6.758045e-03
# wac-wordversionhistoryreactpdf-                     -3.303082   9.562858e-04
# wac-wordimproveboldexperienceonmacchrome-           -3.695102   2.197987e-04
# wac-wordslrcachecolorpickers-                       15.259358   1.426455e-52
# wac-wordlanguageintelligentsuggestion-               3.002265   2.679787e-03
# wac-wordupdatecommanduiperfimprovement-             25.079558  8.312674e-139
# wac-wordmergedparagraphwordidmappingimprovements-    7.809031   5.762942e-15
# wac-licensingisenabled-                              2.346982   1.892618e-02
#
#                                                       [0.025    0.975]  \
# wac-wordmixedjustificationparagraphmultiselectj...  0.230410  0.936643
# wac-worddeprioritizerichtextcontentcontrolaceta... -0.565225 -0.049322
# wac-wordreacttaskpanewithmlr-                       0.018946  0.440724
# wac-wordeditorfirstrunexperiencedatastore-         -0.367179 -0.020622
# wac-wordideas-                                      0.207727  0.309303
# wac-wordlogtasksdetailsfromcpumeter-                0.208697  0.970642
# wac-wordimagegroupcontainerfittopage-               0.267717  0.742506
# wac-wordeditoratmentionsbookmarkendfix-             0.147021  0.588450
# wac-wordeditorcashdashisactivecoauth-               0.046908  0.292545
# wac-wordversionhistoryreactpdf-                    -0.630974 -0.161023
# wac-wordimproveboldexperienceonmacchrome-          -0.681700 -0.209165
# wac-wordslrcachecolorpickers-                       0.487793  0.631567
# wac-wordlanguageintelligentsuggestion-              0.085085  0.405078
# wac-wordupdatecommanduiperfimprovement-             0.701338  0.820250
# wac-wordmergedparagraphwordidmappingimprovements-   0.763503  1.275187
# wac-licensingisenabled-                             0.036510  0.406308
#
#                                                     Odds Ratio    O.R.LB  \
# wac-wordmixedjustificationparagraphmultiselectj...    1.792349  1.259116
# wac-worddeprioritizerichtextcontentcontrolaceta...    0.735449  0.568232
# wac-wordreacttaskpanewithmlr-                         1.258392  1.019126
# wac-wordeditorfirstrunexperiencedatastore-            0.823740  0.692686
# wac-wordideas-                                        1.295005  1.230877
# wac-wordlogtasksdetailsfromcpumeter-                  1.803393  1.232072
# wac-wordimagegroupcontainerfittopage-                 1.657170  1.306977
# wac-wordeditoratmentionsbookmarkendfix-               1.444460  1.158378
# wac-wordeditorcashdashisactivecoauth-                 1.184981  1.048026
# wac-wordversionhistoryreactpdf-                       0.673008  0.532073
# wac-wordimproveboldexperienceonmacchrome-             0.640547  0.505757
# wac-wordslrcachecolorpickers-                         1.750112  1.628717
# wac-wordlanguageintelligentsuggestion-                1.277725  1.088810
# wac-wordupdatecommanduiperfimprovement-               2.139975  2.016449
# wac-wordmergedparagraphwordidmappingimprovements-     2.771379  2.145779
# wac-licensingisenabled-                               1.247834  1.037185
#
#                                                       O.R.UB  \
# wac-wordmixedjustificationparagraphmultiselectj...  2.551403
# wac-worddeprioritizerichtextcontentcontrolaceta...  0.951874
# wac-wordreacttaskpanewithmlr-                       1.553832
# wac-wordeditorfirstrunexperiencedatastore-          0.979590
# wac-wordideas-                                      1.362475
# wac-wordlogtasksdetailsfromcpumeter-                2.639639
# wac-wordimagegroupcontainerfittopage-               2.101195
# wac-wordeditoratmentionsbookmarkendfix-             1.801195
# wac-wordeditorcashdashisactivecoauth-               1.339833
# wac-wordversionhistoryreactpdf-                     0.851272
# wac-wordimproveboldexperienceonmacchrome-           0.811261
# wac-wordslrcachecolorpickers-                       1.880555
# wac-wordlanguageintelligentsuggestion-              1.499419
# wac-wordupdatecommanduiperfimprovement-             2.271067
# wac-wordmergedparagraphwordidmappingimprovements-   3.579372
# wac-licensingisenabled-                             1.501265
#
#                                                            FlightStart  \
# wac-wordmixedjustificationparagraphmultiselectj... 2019-05-29 12:19:23
# wac-worddeprioritizerichtextcontentcontrolaceta... 2019-09-27 22:35:22
# wac-wordreacttaskpanewithmlr-                      2019-05-16 13:34:08
# wac-wordeditorfirstrunexperiencedatastore-         2019-06-14 02:59:07
# wac-wordideas-                                     2019-07-14 01:45:06
# wac-wordlogtasksdetailsfromcpumeter-               2019-06-20 18:59:08
# wac-wordimagegroupcontainerfittopage-              2019-10-09 00:05:40
# wac-wordeditoratmentionsbookmarkendfix-            2019-10-02 14:34:22
# wac-wordeditorcashdashisactivecoauth-              2019-09-24 18:20:12
# wac-wordversionhistoryreactpdf-                    2019-09-03 18:59:53
# wac-wordimproveboldexperienceonmacchrome-          2019-06-24 19:34:36
# wac-wordslrcachecolorpickers-                      2019-05-16 00:19:19
# wac-wordlanguageintelligentsuggestion-             2019-09-11 21:55:22
# wac-wordupdatecommanduiperfimprovement-            2019-05-16 00:19:19
# wac-wordmergedparagraphwordidmappingimprovements-  2019-05-16 00:39:21
# wac-licensingisenabled-                            2019-07-15 17:24:20
#
#                                                              FlightEnd
# wac-wordmixedjustificationparagraphmultiselectj... 2019-09-15 22:30:07
# wac-worddeprioritizerichtextcontentcontrolaceta... 2019-10-30 22:45:13
# wac-wordreacttaskpanewithmlr-                      2019-09-20 17:39:49
# wac-wordeditorfirstrunexperiencedatastore-         2019-08-22 20:29:18
# wac-wordideas-                                     2019-10-30 23:50:06
# wac-wordlogtasksdetailsfromcpumeter-               2019-07-05 16:05:08
# wac-wordimagegroupcontainerfittopage-              2019-10-30 23:50:28
# wac-wordeditoratmentionsbookmarkendfix-            2019-10-30 23:50:28
# wac-wordeditorcashdashisactivecoauth-              2019-10-30 23:50:28
# wac-wordversionhistoryreactpdf-                    2019-10-30 23:30:23
# wac-wordimproveboldexperienceonmacchrome-          2019-09-15 10:19:26
# wac-wordslrcachecolorpickers-                      2019-10-20 10:14:11
# wac-wordlanguageintelligentsuggestion-             2019-10-30 23:50:28
# wac-wordupdatecommanduiperfimprovement-            2019-09-27 22:24:20
# wac-wordmergedparagraphwordidmappingimprovements-  2019-06-12 02:39:11
# wac-licensingisenabled-                            2019-10-30 23:50:28

# %% [markdown]
# If we filter for just StatSig Predictors from model above, it does not improve Log Likelihood:

# %%
logit = sm.Logit(y['word'],X['word'].loc[:,coefficients.index])
flogit = logit.fit()
print(flogit.summary())
coefficients = flogit.summary2().tables[1]
coefficients = coefficients[coefficients['P>|z|']<0.1]
coefficients['Odds Ratio']=np.exp(coefficients['Coef.'])
coefficients['O.R.LB']=np.exp(coefficients['[0.025'])
coefficients['O.R.UB']=np.exp(coefficients['0.975]'])
coefficients.join(flight_durations)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.598956
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    NPS   No. Observations:                25139
# Model:                          Logit   Df Residuals:                    25123
# Method:                           MLE   Df Model:                           15
# Date:                Tue, 12 Nov 2019   Pseudo R-squ.:               -0.002959
# Time:                        17:24:55   Log-Likelihood:                -15057.
# converged:                       True   LL-Null:                       -15013.
#                                         LLR p-value:                     1.000
# ===============================================================================================================================
#                                                                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------
# wac-wordmixedjustificationparagraphmultiselectjustify-          0.7973      0.110      7.261      0.000       0.582       1.013
# wac-worddeprioritizerichtextcontentcontrolacetateforcoauth-    -0.3052      0.131     -2.337      0.019      -0.561      -0.049
# wac-wordreacttaskpanewithmlr-                                   0.0465      0.089      0.522      0.602      -0.128       0.221
# wac-wordeditorfirstrunexperiencedatastore-                     -0.0262      0.082     -0.320      0.749      -0.186       0.134
# wac-wordideas-                                                  0.1897      0.052      3.627      0.000       0.087       0.292
# wac-wordlogtasksdetailsfromcpumeter-                            0.6346      0.193      3.295      0.001       0.257       1.012
# wac-wordimagegroupcontainerfittopage-               0.270696  0.618989
# wac-wordeditoratmentionsbookmarkendfix-             0.192996  0.625089
# wac-wordeditorcashdashisactivecoauth-               0.043272  0.247359
# wac-wordversionhistoryreactpdf-                    -0.720001 -0.286298
# wac-wordimproveboldexperienceonmacchrome-          -0.722205 -0.341873
# wac-wordslrcachecolorpickers-                       0.437415  0.571843
# wac-wordupdatecommanduiperfimprovement-             0.703994  0.813575
# wac-wordmergedparagraphwordidmappingimprovements-   0.882077  1.346805
# wac-licensingisenabled-                             0.088427  0.250299
#
#                                                     Odds Ratio    O.R.LB  \
# wac-wordmixedjustificationparagraphmultiselectj...    2.219581  1.789816
# wac-worddeprioritizerichtextcontentcontrolaceta...    0.736972  0.570531
# wac-wordideas-                                        1.208923  1.091118
# wac-wordlogtasksdetailsfromcpumeter-                  1.886303  1.293267
# wac-wordimagegroupcontainerfittopage-                 1.560245  1.310877
# wac-wordeditoratmentionsbookmarkendfix-               1.505376  1.212878
# wac-wordeditorcashdashisactivecoauth-                 1.156405  1.044222
# wac-wordversionhistoryreactpdf-                       0.604623  0.486752
# wac-wordimproveboldexperienceonmacchrome-             0.587406  0.485680
# wac-wordslrcachecolorpickers-                         1.656372  1.548699
# wac-wordupdatecommanduiperfimprovement-               2.135678  2.021811
# wac-wordmergedparagraphwordidmappingimprovements-     3.047863  2.415912
# wac-licensingisenabled-                               1.184550  1.092455
#
#                                                       O.R.UB  \
# wac-wordmixedjustificationparagraphmultiselectj...  2.752539
# wac-worddeprioritizerichtextcontentcontrolaceta...  0.951969
# wac-wordideas-                                      1.339447
# wac-wordlogtasksdetailsfromcpumeter-                2.751279
# wac-wordimagegroupcontainerfittopage-               1.857050
# wac-wordeditoratmentionsbookmarkendfix-             1.868412
# wac-wordeditorcashdashisactivecoauth-               1.280639
# wac-wordversionhistoryreactpdf-                     0.751039
# wac-wordimproveboldexperienceonmacchrome-           0.710439
# wac-wordslrcachecolorpickers-                       1.771530
# wac-wordupdatecommanduiperfimprovement-             2.255958
# wac-wordmergedparagraphwordidmappingimprovements-   3.845120
# wac-licensingisenabled-                             1.284409
#
#                                                            FlightStart  \
# wac-wordmixedjustificationparagraphmultiselectj... 2019-05-29 12:19:23
# wac-worddeprioritizerichtextcontentcontrolaceta... 2019-09-27 22:35:22
# wac-wordideas-                                     2019-07-14 01:45:06
# wac-wordlogtasksdetailsfromcpumeter-               2019-06-20 18:59:08
# wac-wordimagegroupcontainerfittopage-              2019-10-09 00:05:40
# wac-wordeditoratmentionsbookmarkendfix-            2019-10-02 14:34:22
# wac-wordeditorcashdashisactivecoauth-              2019-09-24 18:20:12
# wac-wordversionhistoryreactpdf-                    2019-09-03 18:59:53
# wac-wordimproveboldexperienceonmacchrome-          2019-06-24 19:34:36
# wac-wordslrcachecolorpickers-                      2019-05-16 00:19:19
# wac-wordupdatecommanduiperfimprovement-            2019-05-16 00:19:19
# wac-wordmergedparagraphwordidmappingimprovements-  2019-05-16 00:39:21
# wac-licensingisenabled-                            2019-07-15 17:24:20
#
#                                                              FlightEnd
# wac-wordmixedjustificationparagraphmultiselectj... 2019-09-15 22:30:07
# wac-worddeprioritizerichtextcontentcontrolaceta... 2019-10-30 22:45:13
# wac-wordideas-                                     2019-10-30 23:50:06
# wac-wordlogtasksdetailsfromcpumeter-               2019-07-05 16:05:08
# wac-wordimagegroupcontainerfittopage-              2019-10-30 23:50:28
# wac-wordeditoratmentionsbookmarkendfix-            2019-10-30 23:50:28
# wac-wordeditorcashdashisactivecoauth-              2019-10-30 23:50:28
# wac-wordversionhistoryreactpdf-                    2019-10-30 23:30:23
# wac-wordimproveboldexperienceonmacchrome-          2019-09-15 10:19:26
# wac-wordslrcachecolorpickers-                      2019-10-20 10:14:11
# wac-wordupdatecommanduiperfimprovement-            2019-09-27 22:24:20
# wac-wordmergedparagraphwordidmappingimprovements-  2019-06-12 02:39:11
# wac-licensingisenabled-                            2019-10-30 23:50:28

# %% [markdown]
# ## PowerPoint

# %%
print('PowerPoint AllUp MODEL')
logit = sm.Logit(y['pp'],X['pp'])
logit.
flogit = logit.fit()
print(flogit.summary())
coefficients = flogit.summary2().tables[1]
coefficients = coefficients[coefficients['P>|z|']<0.1]
coefficients['Odds Ratio']=np.exp(coefficients['Coef.'])
coefficients['O.R.LB']=np.exp(coefficients['[0.025'])
coefficients['O.R.UB']=np.exp(coefficients['0.975]'])
coefficients.join(flight_durations)
# Out:
# PowerPoint AllUp MODEL
# Optimization terminated successfully.
#          Current function value: 0.567854
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    NPS   No. Observations:                18610
# Model:                          Logit   Df Residuals:                    18592
# Method:                           MLE   Df Model:                           17
# Date:                Wed, 18 Dec 2019   Pseudo R-squ.:                -0.01950
# Time:                        11:17:58   Log-Likelihood:                -10568.
# converged:                       True   LL-Null:                       -10366.
#                                         LLR p-value:                     1.000
# ==============================================================================================================
#                                                  coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# ppt-appcommandsquickcheck-                    -0.1308      0.149     -0.876      0.381      -0.423       0.162
# ppt-cleanstaleomexcachebyrefresh-             -0.0438      0.084     -0.524      0.600      -0.207       0.120
# ppt-designerdashboardtest-                     0.0809      0.055      1.475      0.140      -0.027       0.188
# ppt-dictation-                                 0.2917      0.283      1.030      0.303      -0.263       0.847
# ppt-formatpainterapplyremapped-                0.5539      0.046     12.057      0.000       0.464       0.644
# ppt-freemiumupsellheaderui-                   -0.1752      0.098     -1.791      0.073      -0.367       0.017
# ppt-helptabwhatsnewenabled-                    0.4394      0.090      4.897      0.000       0.264       0.615
# ppt-linktoslide-                               0.2110      0.096      2.206      0.027       0.024       0.398
# ppt-newaugloopmanager-                         0.1919      0.800      0.240      0.811      -1.377       1.761
# ppt-newcommentdraftingapiisenabled-            0.1186      0.048      2.447      0.014       0.024       0.214
# ppt-newideas-                                  0.6150      0.030     20.590      0.000       0.556       0.674
# ppt-pasteslidekeepsourceformattingdefault-    -0.0301      0.065     -0.465      0.642      -0.157       0.097
# ppt-pptnewcommentbuttoninpane-                 0.7905      0.081      9.702      0.000       0.631       0.950
# ppt-pptsharedcommentsfluentui-                 0.3478      0.043      8.083      0.000       0.263       0.432
# ppt-sendshuttingdownbeaconrequests-           -0.0028      0.089     -0.032      0.975      -0.177       0.172
# ppt-slrcombinedoverflowmenus-                  0.8495      0.777      1.093      0.274      -0.673       2.372
# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
rf = RandomForestClassifier(random_state=0)
param_grid = { 
    'n_estimators': [50, 100, 250, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [2,5,10,None],
    'oob_score': [True,False]}

CV_rfc = GridSearchCV(estimator=rf, n_jobs=-1, param_grid=param_grid, verbose=10, scoring='neg_log_loss',cv= 5)
CV_rfc.fit(X_train, y_train)
print(CV_rfc.best_params_, CV_rfc.best_score_)

# %%
coefficients
# Out:
#                                         Coef.  Std.Err.          z  \
# ppt-formatpainterapplyremapped-      0.553948  0.045943  12.057366
# ppt-freemiumupsellheaderui-         -0.175179  0.097833  -1.790595
# ppt-helptabwhatsnewenabled-          0.439410  0.089722   4.897484
# ppt-linktoslide-                     0.210955  0.095621   2.206153
# ppt-newcommentdraftingapiisenabled-  0.118622  0.048484   2.446626
# ppt-newideas-                        0.615018  0.029869  20.590226
# ppt-pptnewcommentbuttoninpane-       0.790493  0.081474   9.702372
# ppt-pptsharedcommentsfluentui-       0.347758  0.043024   8.082956
# ppt-textformatpainter-              -0.184535  0.088109  -2.094391
# ppt-wopitokenrefresh-                0.499106  0.069061   7.226994
#
#                                             P>|z|    [0.025    0.975]  \
# ppt-formatpainterapplyremapped-      1.773647e-33  0.463902  0.643994
# ppt-freemiumupsellheaderui-          7.335833e-02 -0.366928  0.016570
# ppt-helptabwhatsnewenabled-          9.707166e-07  0.263559  0.615262
# ppt-linktoslide-                     2.737330e-02  0.023541  0.398369
# ppt-newcommentdraftingapiisenabled-  1.442003e-02  0.023595  0.213648
# ppt-newideas-                        3.357974e-94  0.556475  0.673561
# ppt-pptnewcommentbuttoninpane-       2.945707e-22  0.630807  0.950180
# ppt-pptsharedcommentsfluentui-       6.321536e-16  0.263433  0.432083
# ppt-textformatpainter-               3.622515e-02 -0.357226 -0.011844
# ppt-wopitokenrefresh-                4.938007e-13  0.363748  0.634463
#
#                                      Odds Ratio    O.R.LB    O.R.UB
# ppt-formatpainterapplyremapped-        1.740110  1.590267  1.904071
# ppt-freemiumupsellheaderui-            0.839307  0.692860  1.016708
# ppt-helptabwhatsnewenabled-            1.551792  1.301554  1.850141
# ppt-linktoslide-                       1.234857  1.023820  1.489393
# ppt-newcommentdraftingapiisenabled-    1.125944  1.023876  1.238187
# ppt-newideas-                          1.849690  1.744512  1.961209
# ppt-pptnewcommentbuttoninpane-         2.204483  1.879126  2.586174
# ppt-pptsharedcommentsfluentui-         1.415890  1.301390  1.540463
# ppt-textformatpainter-                 0.831491  0.699614  0.988226
# ppt-wopitokenrefresh-                  1.647248  1.438712  1.886010

# %%
1 - coefficients['Odds Ratio']
# Out:
# ppt-formatpainterapplyremapped-       -0.740110
# ppt-freemiumupsellheaderui-            0.160693
# ppt-helptabwhatsnewenabled-           -0.551792
# ppt-linktoslide-                      -0.234857
# ppt-newcommentdraftingapiisenabled-   -0.125944
# ppt-newideas-                         -0.849690
# ppt-pptnewcommentbuttoninpane-        -1.204483
# ppt-pptsharedcommentsfluentui-        -0.415890
# ppt-textformatpainter-                 0.168509
# ppt-wopitokenrefresh-                 -0.647248
# Name: Odds Ratio, dtype: float64

# %%
def odd_v_prob(p1,p2):
    '''representing change in probability and corresponding change in odds
    p1: initial probability
    p2: updated probability'''
    p_change = p2-p1
    o1 = p1/(1-p1)
    o2 = p2/(1-p2)
    o_change = o2-o1
    return p_change, o_change

print(odd_v_prob(0.1,0.6))
print(odd_v_prob(0.2,0.7))
print(odd_v_prob(0.3,0.8))
# Out:
# (0.5, 1.3888888888888886)
# (0.49999999999999994, 2.083333333333333)
# (0.5, 3.571428571428572)

# %%
coefficients
# Out:
#                                         Coef.  Std.Err.          z  \
# ppt-formatpainterapplyremapped-      0.553948  0.045943  12.057366
# ppt-freemiumupsellheaderui-         -0.175179  0.097833  -1.790595
# ppt-helptabwhatsnewenabled-          0.439410  0.089722   4.897484
# ppt-linktoslide-                     0.210955  0.095621   2.206153
# ppt-newcommentdraftingapiisenabled-  0.118622  0.048484   2.446626
# ppt-newideas-                        0.615018  0.029869  20.590226
# ppt-pptnewcommentbuttoninpane-       0.790493  0.081474   9.702372
# ppt-pptsharedcommentsfluentui-       0.347758  0.043024   8.082956
# ppt-textformatpainter-              -0.184535  0.088109  -2.094391
# ppt-wopitokenrefresh-                0.499106  0.069061   7.226994
#
#                                             P>|z|    [0.025    0.975]  \
# ppt-formatpainterapplyremapped-      1.773647e-33  0.463902  0.643994
# ppt-freemiumupsellheaderui-          7.335833e-02 -0.366928  0.016570
# ppt-helptabwhatsnewenabled-          9.707166e-07  0.263559  0.615262
# ppt-linktoslide-                     2.737330e-02  0.023541  0.398369
# ppt-newcommentdraftingapiisenabled-  1.442003e-02  0.023595  0.213648
# ppt-newideas-                        3.357974e-94  0.556475  0.673561
# ppt-pptnewcommentbuttoninpane-       2.945707e-22  0.630807  0.950180
# ppt-pptsharedcommentsfluentui-       6.321536e-16  0.263433  0.432083
# ppt-textformatpainter-               3.622515e-02 -0.357226 -0.011844
# ppt-wopitokenrefresh-                4.938007e-13  0.363748  0.634463
#
#                                      Odds Ratio    O.R.LB    O.R.UB
# ppt-formatpainterapplyremapped-        1.740110  1.590267  1.904071
# ppt-freemiumupsellheaderui-            0.839307  0.692860  1.016708
# ppt-helptabwhatsnewenabled-            1.551792  1.301554  1.850141
# ppt-linktoslide-                       1.234857  1.023820  1.489393
# ppt-newcommentdraftingapiisenabled-    1.125944  1.023876  1.238187
# ppt-newideas-                          1.849690  1.744512  1.961209
# ppt-pptnewcommentbuttoninpane-         2.204483  1.879126  2.586174
# ppt-pptsharedcommentsfluentui-         1.415890  1.301390  1.540463
# ppt-textformatpainter-                 0.831491  0.699614  0.988226
# ppt-wopitokenrefresh-                  1.647248  1.438712  1.886010

# %%
prob_interpretation = coefficients['Odds Ratio'].round(1)*0.5 #- 0.5

# %%
prob_interpretation.mask(prob_interpretation>1,0.99#,0.5
                        )
# Out:
# ppt-formatpainterapplyremapped-        0.85
# ppt-freemiumupsellheaderui-            0.40
# ppt-helptabwhatsnewenabled-            0.80
# ppt-linktoslide-                       0.60
# ppt-newcommentdraftingapiisenabled-    0.55
# ppt-newideas-                          0.90
# ppt-pptnewcommentbuttoninpane-         0.99
# ppt-pptsharedcommentsfluentui-         0.70
# ppt-textformatpainter-                 0.40
# ppt-wopitokenrefresh-                  0.80
# Name: Odds Ratio, dtype: float64

# %% [markdown]
# ## Overall
#
# Flights that appear in each of the three apps

# %%
print('SATURATED MODEL')
logit = sm.Logit(y['all'],X['all'])
flogit = logit.fit()
print(flogit.summary())
coefficients = flogit.summary2().tables[1]
coefficients = coefficients[coefficients['P>|z|']<0.1]
coefficients['Odds Ratio']=np.exp(coefficients['Coef.'])
coefficients['O.R.LB']=np.exp(coefficients['[0.025'])
coefficients['O.R.UB']=np.exp(coefficients['0.975]'])
coefficients.join(flight_durations)
# Out:
# SATURATED MODEL
# Optimization terminated successfully.
#          Current function value: 0.593597
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    NPS   No. Observations:                67068
# Model:                          Logit   Df Residuals:                    67034
# Method:                           MLE   Df Model:                           33
# Date:                Tue, 12 Nov 2019   Pseudo R-squ.:                -0.01688
# Time:                        16:45:19   Log-Likelihood:                -39811.
# converged:                       True   LL-Null:                       -39150.
#                                         LLR p-value:                     1.000
# ===============================================================================================================================
#                                                                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------
# wac-worddeprioritizerichtextcontentcontrolacetateforcoauth-    -0.1022      0.084     -1.218      0.223      -0.267       0.062
# wac-minimizeintelligentplaceholderwork-                         0.4662      0.132      3.540      0.000       0.208       0.724
# wac-wordwordoauthtestappaadtokenretrieval-                      0.2310      0.025      9.110      0.000       0.181       0.281
# wac-worddefinenewbullettablecellclassname-                     -0.0580      0.076     -0.767      0.443      -0.206       0.090
# wac-wordwordoauthtestappmsatokenretrieval-                      0.8611      0.153      5.642      0.000       0.562       1.160
# wac-wordimagegroupcontainerfittopage-                           0.2294      0.077      2.995      0.003       0.079       0.380
# wac-wordshowpasteoptionsincontextmenu-                          0.3093      0.055      5.610      0.000       0.201       0.417
# wac-worduseaadforfileupload-                                    0.3484      0.033     10.551      0.000       0.284       0.413
# firstrelease-                                                   0.3396      0.029     11.780      0.000       0.283       0.396
# xls-overridebrowsershortcuts-                                   0.3383      0.031     10.971      0.000       0.278       0.399
# wac-wordeditorcashdashisactivecoauth-                          -0.2559      0.043     -5.895      0.000      -0.341      -0.171
# wac-wordkeepmaxlastknownheight-                                 0.2014      0.043      4.659      0.000       0.117       0.286
# wac-ocpsisenabled-                                              0.0837      0.043      1.927      0.054      -0.001       0.169
# wac-wordclearformattingtrackchanges-                           -0.0477      0.109     -0.439      0.661      -0.261       0.165
# docowneridtestaa-                                               0.1763      0.062      2.836      0.005       0.054       0.298
# wac-owaunifiedapp-                                              0.1442      0.024      6.062      0.000       0.098       0.191
# canary-user-                                                   -0.0305      0.030     -1.016      0.310      -0.089       0.028
# wac-wordcloneatmentionpropertiesinhyperlink-                   -0.1532      0.099     -1.553      0.121      -0.347       0.040
