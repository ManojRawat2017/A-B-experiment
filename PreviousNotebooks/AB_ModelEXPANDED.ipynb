# %% [markdown]
# Objective: Expand NPS Predictive Model based on Flight Control/Treatment pairs to newer datasets and also to more apps than just Excel.

# %%
import math
import pandas as pd
import numpy as np
import datetime
import sklearn.tree
from graphviz import Source
from IPython.display import SVG
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.feature_selection import RFE
import os

from sklearn.linear_model import LogisticRegressionCV, LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb

import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats

def transform_rating(rating):
    '''Input: Column of Data with NPS Field (on a scale of 1 to 5...)
    Output: Column with either Promoter/Detractor/Passive label, or the corresponding weights, based on datatype'''
    
    if rating == 5:
        return 100
    elif rating <= 3:
        return -100
    elif rating == 4:
        return 0
    else:
        return np.nan

# %%
Word_df = pd.read_csv('Word_updated_data.tsv', sep='\t')

Excel_df = pd.read_csv('Excel_updated_data.tsv', sep='\t')
PP_df = pd.read_csv('PowerPoint_updated_data.tsv', sep='\t')
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def make_AB_dataset(df,prefixes):
    '''df: initial input dataframe of flight data
    prefixes: flights have prefixes - this arg is a list for which prefixes we want to filter on'''
    df = df[df['AudienceGroup']=='Production']
    df['Date'] = pd.to_datetime(df['Date'])
    flights = df.FlightId.astype(str).unique()
    controls = [f for f in flights if f.endswith('-c') or f.__contains__('control')]
    treatments = [f for f in flights if f.endswith('-t') or f.__contains__('treatment')]
    neither = [f for f in flights if (f not in controls) and (f not in treatments)]
    union = {'controls':[c.rstrip('control') for c in controls],'treatments':[t.rstrip('treatments') for t in treatments]}
    no_control = list(set(union['treatments'])-set(union['controls']))
    control_treatment_pairs = list(set(union['treatments'])-set(no_control))
    df['FlightPair']=df['FlightId'].astype(str).map(lambda x: x.rstrip('control'))
    df['FlightPair']=df['FlightPair'].map(lambda x: x.rstrip('treatment'))
    df['FlightPair'].replace('docowner-canary','canary-docowner',inplace=True)
    
    
    ab_df = df[df.FlightId.notnull()]
    ab_df.drop_duplicates(keep='last', inplace=True)
    print(ab_df.shape, ' before filtering out non-pairs')
    ab_df = ab_df[ab_df['FlightPair'].isin(control_treatment_pairs)]
    print(ab_df.shape, ' after filtering out non-pairs')
    ab_df.loc[ab_df.FlightId.str.endswith('-c'),'Group'] = 'Control'
    ab_df.loc[ab_df.FlightId.str.endswith('control'),'Group'] = 'Control'
    ab_df.loc[ab_df.FlightId.str.endswith('-t'),'Group'] = 'Treatment'
    ab_df.loc[ab_df.FlightId.str.endswith('treatment'),'Group'] = 'Treatment'
    ab_df.loc[ab_df.FlightId.str.endswith('-c'),'Flight'] = 0
    ab_df.loc[ab_df.FlightId.str.endswith('control'),'Flight'] = 0
    ab_df.loc[ab_df.FlightId.str.endswith('-t'),'Flight'] = 1
    ab_df.loc[ab_df.FlightId.str.endswith('treatment'),'Flight'] = 1
    ab_df = ab_df[ab_df.Flight.notnull()]
    ab_df['NPS'] = ab_df['Rating'].apply(transform_rating)
    ab_df = ab_df.sort_values(by='Date')
    value_key = ab_df.sort_values(by='Date').groupby(['OcvId'])['NPS'].last().to_dict()
    exp_df = ab_df.groupby(['OcvId','FlightPair'])['Flight'].last().unstack()
    print('Feature Matrix should have ',ab_df.OcvId.nunique(), ' rows and ',ab_df.FlightPair.nunique(),' columns')
    print('Final Shape:',exp_df.shape)
    if prefixes: #i.e. if the input list is empty:
        for p in prefixes:
            exp_df = exp_df.iloc[:,exp_df.columns.str.startswith(p)]
    exp_df['NPS'] = exp_df.index.map(value_key)
    return exp_df.fillna(0)

#excel_df = make_AB_dataset(Excel_df,['xls'])

# %%
def get_flight_durations():
    ''' no inputs/arguments, just make sure you have all of the Tabular Flight data files you are using.'''
    df = pd.concat([Excel_df[Excel_df['AudienceGroup']=='Production'][Excel_df.FlightId.notnull()],
                    Word_df[Word_df['AudienceGroup']=='Production'][Word_df.FlightId.notnull()],
                    PP_df[PP_df['AudienceGroup']=='Production'][PP_df.FlightId.notnull()]])
    #df = df[df['AudienceGroup']=='Production']
    df['Date'] = pd.to_datetime(df['Date'])
    flights = df.FlightId.astype(str).unique()
    controls = [f for f in flights if f.endswith('-c') or f.__contains__('control')]
    treatments = [f for f in flights if f.endswith('-t') or f.__contains__('treatment')]
    neither = [f for f in flights if (f not in controls) and (f not in treatments)]
    union = {'controls':[c.rstrip('control') for c in controls],'treatments':[t.rstrip('treatments') for t in treatments]}
    no_control = list(set(union['treatments'])-set(union['controls']))
    control_treatment_pairs = list(set(union['treatments'])-set(no_control))
    df['FlightPair']=df['FlightId'].astype(str).map(lambda x: x.rstrip('control'))
    df['FlightPair']=df['FlightPair'].map(lambda x: x.rstrip('treatment'))
    
    print('Flight Pairs Assigned')
    
    ab_df = df[df.FlightPair.notnull()]
    #ab_df.drop_duplicates(keep='last', inplace=True)
    ab_df = ab_df[ab_df['FlightPair'].isin(control_treatment_pairs)]
    flight_starts = ab_df.sort_values(by='Date').groupby(['FlightPair'])['Date'].first()
    flight_ends = ab_df.sort_values(by='Date').groupby(['FlightPair'])['Date'].last()
    flight_durations = pd.concat([flight_starts,flight_ends],axis=1)
    flight_durations.columns = ['FlightStart','FlightEnd']
    return flight_durations
    
flight_durations = get_flight_durations()
# Out:
# Flight Pairs Assigned

# %%
flight_durations.to_csv('FlightsSeptember.csv')

# %%
excel_df = make_AB_dataset(Excel_df,[])
word_df = make_AB_dataset(Word_df,[])
pp_df = make_AB_dataset(PP_df,[])
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (559722, 40)  before filtering out non-pairs
# (367873, 40)  after filtering out non-pairs
# Feature Matrix should have  16624  rows and  119  columns
# Final Shape: (16624, 119)
# (980393, 40)  before filtering out non-pairs
# (637576, 40)  after filtering out non-pairs
# Feature Matrix should have  17466  rows and  193  columns
# Final Shape: (17466, 193)
# (275253, 40)  before filtering out non-pairs
# (140480, 40)  after filtering out non-pairs
# Feature Matrix should have  12963  rows and  48  columns
# Final Shape: (12963, 48)

# %%
excel_flights = list(excel_df.columns)
word_flights = list(word_df.columns)
common_flights = list(set(excel_flights).intersection(word_flights))
pp_flights = list(pp_df.columns)
common_flights = list(set(common_flights).intersection(pp_flights))

# %%
common_flights.remove('NPS')

# %%
common_flights
# Out:
# ['docowner-canary-',
#  'wac-wordclearformattingtrackchanges-',
#  'wac-box4directprinthidesensitiveparameters-',
#  'xls-overridebrowsershortcuts-',
#  'wac-wordeditorcashdashisactivecoauth-',
#  'wac-wordshowpasteoptionsincontextmenu-',
#  'canary-docowner-',
#  'canary2-',
#  'wac-worduseaadforfileupload-',
#  'wac-worddeprioritizerichtextcontentcontrolacetateforcoauth-',
#  'wacdash-',
#  'wac-wordsdxpreloadpackagelist-',
#  'firstrelease-',
#  'wac-wordpreserveverbonredirect-',
#  'wac-wordwordoauthtestappmsatokenretrieval-',
#  'xls-removescrolltofirstandlastsheettabnavbuttons-',
#  'docowneridtestaa-',
#  'wac-owaunifiedapp-',
#  'useridtestaa-',
#  'canary-',
#  'wac-mergemissingeopfix-',
#  'xls-customsortforallrangetypes-',
#  'wac-minimizeintelligentplaceholderwork-',
#  'wac-wordwordoauthtestappaadtokenretrieval-',
#  'wac-wordkeepmaxlastknownheight-']

# %%
dc = ['docowner-canary-','canary-docowner-',
     'canary2','canary-']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f4ccc8723899> in <module>()
# ----> 1 common_flights
#
# NameError: name 'common_flights' is not defined

# %%
X = {'excel':excel_df.iloc[:,excel_df.columns.str.startswith('xls')],
     'word':word_df.iloc[:,word_df.columns.str.startswith('wac')],
     'pp':pp_df.iloc[:,pp_df.columns.str.startswith('pp')],
     'all':pd.concat([excel_df,word_df,pp_df]).loc[:,common_flights]}
y = {'excel':excel_df['NPS'].replace([100,0],1).replace(-100,0)
     ,'word':word_df['NPS'].replace([100,0],1).replace(-100,0),
     'pp':pp_df['NPS'].replace([100,0],1).replace(-100,0),
     'all':pd.concat([excel_df,word_df,pp_df])['NPS'].replace([100,0],1).replace(-100,0)}
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
print(X['excel'].shape, y['excel'].shape)
print(X['word'].shape, y['word'].shape)
print(X['pp'].shape, y['pp'].shape)
print(X['all'].shape, y['all'].shape)
# Out:
# (16624, 90) (16624,)
# (17466, 177) (17466,)
# (12963, 14) (12963,)
# (47053, 25) (47053,)

# %%
model_perfs = pd.DataFrame(columns=['Logistic','RandomForest','GradientBoosting'])
for key in ['excel','word','pp','all']:
################################################ WHEN PREDICTORS ARE BINARY (1 for Treatment, 0 otherwise)
    logit = LogisticRegression().fit(X[key],y[key])
    rf = RandomForestClassifier(random_state=0).fit(X[key],y[key])
    gb = xgb.XGBClassifier(random_state=0, n_jobs=4).fit(X[key],y[key])
    
    log_acc = round(logit.score(X[key],y[key]),3)
    rf_acc = round(rf.score(X[key],y[key]),3)
    gb_acc = round(gb.score(X[key],y[key]),3)
    
    log_acc = round(logit.score(X[key],y[key]),3)
    rf_acc = round(rf.score(X[key],y[key]),3)
    gb_acc = round(gb.score(X[key],y[key]),3)


    model_perfs.loc[key+'Accuracy']=[log_acc,rf_acc,gb_acc]
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
model_perfs
# Out:
#                Logistic  RandomForest  GradientBoosting
# excelAccuracy     0.743         0.836             0.743
# wordAccuracy      0.750         0.962             0.750
# ppAccuracy        0.770         0.771             0.770
# allAccuracy       0.753         0.762             0.753

# %% [markdown]
# ## Excel

# %%
X_train, X_test, y_train, y_test = train_test_split(X['excel'], y['excel'], test_size=0.1)

# %%
### ONLY RUN IF THERE IS NO OUTPUT ###
rf = RandomForestClassifier(random_state=0)
param_grid = { 
    'n_estimators': [50, 100, 250, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [2,5,10,None],
    'oob_score': [True,False]}

CV_rfc = GridSearchCV(estimator=rf, n_jobs=-1, param_grid=param_grid, verbose=10, scoring='neg_log_loss',cv= 5)
CV_rfc.fit(X_train, y_train)
print(CV_rfc.best_params_, CV_rfc.best_score_)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   40.8s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   41.6s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   44.3s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   49.2s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 480 out of 480 | elapsed: 14.9min finished
# {'max_depth': 5, 'max_features': 'auto', 'n_estimators': 100, 'oob_score': True} -0.559152758912611

# %%
print(RandomForestClassifier(random_state=0).fit(X_train,
                                           y_train).score(X_test,y_test))


rfc = RandomForestClassifier(random_state = 0, n_estimators = 100,
                      max_depth=5,oob_score=True)
rfc.fit(X_train,y_train)
print(rfc.score(X_test,y_test))

learners = rfc.feature_importances_.argsort()[::-1]

features = pd.DataFrame(X_train.columns[learners], rfc.feature_importances_[learners])
features = features[features.index>0.025]
features
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.7017438364401684
# 0.7432351172579675
#                                        FlightPair
# 0.106023           xls-tabletextcontrastacccheck-
# 0.069156              xls-newcommentbuttoninpane-
# 0.049805               xls-slrcachecomboboxmenus-
# 0.045594                   xls-slrcachegalleries-
# 0.044594          xls-namedsheetviewspassivetest-
# 0.039080                               xls-ideas-
# 0.036940        xls-satoriforthirdpartiesenabled-
# 0.035142            xls-listfieldlookupoptimized-
# 0.030356            xls-workbookcachedigestreset-
# 0.029938              xls-helptabwhatsnewenabled-
# 0.027572  xls-chartfloatingobjectcontrolfallback-

# %%
print(LogisticRegression().fit(X_train,y_train).score(X_test,y_test), ' -->...')

for i in [1,2,3,4,5,10,15,20,25,50,75,100]:
    print('Score with Top ',i,' Features:')
    logit = LogisticRegression(solver='liblinear')

    rfe = RFE(logit,i)
    rfe = rfe.fit(X_train,y_train.values.ravel())

    rfe.support_
    rfe.ranking_

    #identified columns Recursive Feature Elimination
    idc_rfe = pd.DataFrame({"rfe_support" :rfe.support_,
                           "columns" : [i for i in X_train.columns],
                           "ranking" : rfe.ranking_,
                          })
    cols = idc_rfe[idc_rfe["rfe_support"] == True]["columns"].tolist()


    #separating train and test data
    train_rfe_X = X_train[cols]
    train_rfe_y = y_train.copy()

    test_rfe_X = X_test[cols]
    test_rfe_y = y_test.copy()


    logit_rfe = LogisticRegression(class_weight=None, dual=False, fit_intercept=True,
              intercept_scaling=1, max_iter=100, #n_jobs=4,
              penalty='l2', random_state=None, solver='liblinear', #tol=0.0001,
              verbose=0, warm_start=False)

    logit_rfe.fit(train_rfe_X, train_rfe_y)
    print(logit_rfe.score(test_rfe_X,test_rfe_y))
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.7414311485267588  -->...
# Score with Top  1  Features:
# 0.7432351172579675
# Score with Top  2  Features:
# 0.7432351172579675
# Score with Top  3  Features:
# 0.7432351172579675
# Score with Top  4  Features:
# 0.7432351172579675
# Score with Top  5  Features:
# 0.7432351172579675
# Score with Top  10  Features:
# 0.7432351172579675
# Score with Top  15  Features:
# 0.7432351172579675
# Score with Top  20  Features:
# 0.7432351172579675
# Score with Top  25  Features:
# 0.7432351172579675
# Score with Top  50  Features:
# 0.7432351172579675
# Score with Top  75  Features:
# 0.7420324714371618
# Score with Top  100  Features:
# 0.7414311485267588

# %%
print(logit.fit(X_train,y_train).score(X_test,y_test), ' -->...')
logit_rfe.score(test_rfe_X,test_rfe_y)
# Out:
# 0.7414311485267588  -->...
# 0.7414311485267588

# %%
logit = LogisticRegression(solver='liblinear')

rfe = RFE(logit,5)
rfe = rfe.fit(X_train,y_train.values.ravel())

rfe.ranking_

#identified columns Recursive Feature Elimination
idc_rfe = pd.DataFrame({"rfe_support" :rfe.support_,
                       "columns" : [i for i in X_train.columns],
                       "ranking" : rfe.ranking_,
                      })

cols = idc_rfe[idc_rfe["rfe_support"] == True]["columns"].tolist()

# %%
cols.extend(features.FlightPair.values.tolist())
cols = list(set(cols))

logit = sm.Logit(y['excel'],X['excel'].loc[:,cols])
flogit = logit.fit()
print(flogit.summary())

coefficients = flogit.summary2().tables[1]
coefficients = coefficients[coefficients['P>|z|']<0.1]
coefficients['Odds Ratio']=np.exp(coefficients['Coef.'])
coefficients['O.R.LB']=np.exp(coefficients['[0.025'])
coefficients['O.R.UB']=np.exp(coefficients['0.975]'])
coefficients.join(flight_durations)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.569723
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    NPS   No. Observations:                16624
# Model:                          Logit   Df Residuals:                    16609
# Method:                           MLE   Df Model:                           14
# Date:                Thu, 17 Oct 2019   Pseudo R-squ.:               0.0008208
# Time:                        15:17:15   Log-Likelihood:                -9471.1
# converged:                      False   LL-Null:                       -9478.9
#                                         LLR p-value:                    0.3409
# =====================================================================================================================
#                                                         coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# xls-slrcachegalleries-                                0.2894      0.055      5.292      0.000       0.182       0.397
# xls-tabletextcontrastacccheck-                        0.2972      0.070      4.233      0.000       0.160       0.435
# xls-reconnectsessiononuserinteration-                -0.6928      0.210     -3.302      0.001      -1.104      -0.282
# xls-freemiumupsellheaderui-                           0.5872      0.124      4.724      0.000       0.344       0.831
# xls-newcommentbuttoninpane-                          -0.0470      0.068     -0.690      0.490      -0.180       0.086
# xls-slrcachecomboboxmenus-                            0.3472      0.065      5.357      0.000       0.220       0.474
# xls-namedsheetviewspassivetest-                       0.1779      0.057      3.113      0.002       0.066       0.290
# xls-chartfloatingobjectcontrolfallback-               0.1538      0.070      2.182      0.029       0.016       0.292
# xls-workbookcachedigestreset-                        -0.0136      0.057     -0.240      0.810      -0.125       0.098
# xls-listfieldlookupoptimized-                         0.2164      0.065      3.319      0.001       0.089       0.344
# xls-ideas-                                            0.1451      0.058      2.514      0.012       0.032       0.258
# xls-removescrolltofirstandlastsheettabnavbuttons-     0.4987      0.328      1.520      0.129      -0.144       1.142
# xls-helptabwhatsnewenabled-                           0.2175      0.070      3.106      0.002       0.080       0.355
# xls-gridcanvasrendering-                             19.1001   9474.723      0.002      0.998   -1.86e+04    1.86e+04
# xls-satoriforthirdpartiesenabled-                     0.1966      0.108      1.814      0.070      -0.016       0.409
# =====================================================================================================================
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                                             Coef.  Std.Err.         z  \
# xls-slrcachegalleries-                   0.289394  0.054687  5.291780
# xls-tabletextcontrastacccheck-           0.297222  0.070213  4.233168
# xls-reconnectsessiononuserinteration-   -0.692824  0.209844 -3.301622
# xls-freemiumupsellheaderui-              0.587166  0.124295  4.723966
# xls-slrcachecomboboxmenus-               0.347177  0.064810  5.356834
# xls-namedsheetviewspassivetest-          0.177923  0.057159  3.112784
# xls-chartfloatingobjectcontrolfallback-  0.153802  0.070488  2.181979
# xls-listfieldlookupoptimized-            0.216439  0.065221  3.318559
# xls-ideas-                               0.145126  0.057737  2.513564
# xls-helptabwhatsnewenabled-              0.217469  0.070019  3.105850
# xls-satoriforthirdpartiesenabled-        0.196623  0.108365  1.814458
#
#                                                 P>|z|    [0.025    0.975]  \
# xls-slrcachegalleries-                   1.211313e-07  0.182209  0.396580
# xls-tabletextcontrastacccheck-           2.304221e-05  0.159608  0.434836
# xls-reconnectsessiononuserinteration-    9.612758e-04 -1.104110 -0.281538
# xls-freemiumupsellheaderui-              2.312895e-06  0.343552  0.830780
# xls-slrcachecomboboxmenus-               8.469274e-08  0.220151  0.474202
# xls-namedsheetviewspassivetest-          1.853317e-03  0.065894  0.289953
# xls-chartfloatingobjectcontrolfallback-  2.911112e-02  0.015649  0.291956
# xls-listfieldlookupoptimized-            9.048324e-04  0.088609  0.344269
# xls-ideas-                               1.195180e-02  0.031963  0.258289
# xls-helptabwhatsnewenabled-              1.897328e-03  0.080234  0.354704
# xls-satoriforthirdpartiesenabled-        6.960727e-02 -0.015768  0.409013
#
#                                          Odds Ratio    O.R.LB    O.R.UB  \
# xls-slrcachegalleries-                     1.335618  1.199865  1.486731
# xls-tabletextcontrastacccheck-             1.346114  1.173051  1.544710
# xls-reconnectsessiononuserinteration-      0.500161  0.331506  0.754622
# xls-freemiumupsellheaderui-                1.798883  1.409947  2.295108
# xls-slrcachecomboboxmenus-                 1.415067  1.246265  1.606731
# xls-namedsheetviewspassivetest-            1.194734  1.068113  1.336365
# xls-chartfloatingobjectcontrolfallback-    1.166260  1.015772  1.339044
# xls-listfieldlookupoptimized-              1.241647  1.092653  1.410959
# xls-ideas-                                 1.156185  1.032480  1.294713
# xls-helptabwhatsnewenabled-                1.242927  1.083541  1.425758
# xls-satoriforthirdpartiesenabled-          1.217285  0.984356  1.505332
#
#                                                 FlightStart  \
# xls-slrcachegalleries-                  2019-05-31 18:09:09
# xls-tabletextcontrastacccheck-          2019-05-01 02:10:10
# xls-reconnectsessiononuserinteration-   2019-08-04 12:29:06
# xls-freemiumupsellheaderui-             2019-05-01 01:34:07
# xls-slrcachecomboboxmenus-              2019-05-01 16:00:05
# xls-namedsheetviewspassivetest-         2019-05-02 14:35:04
# xls-chartfloatingobjectcontrolfallback- 2019-06-04 12:25:32
# xls-listfieldlookupoptimized-           2019-05-22 22:49:04
# xls-ideas-                              2019-05-01 09:20:20
# xls-helptabwhatsnewenabled-             2019-05-21 19:29:36
# xls-satoriforthirdpartiesenabled-       2019-05-01 02:20:05
#
#                                                   FlightEnd
# xls-slrcachegalleries-                  2019-09-29 23:55:07
# xls-tabletextcontrastacccheck-          2019-07-15 18:10:07
# xls-reconnectsessiononuserinteration-   2019-08-15 10:15:38
# xls-freemiumupsellheaderui-             2019-09-29 23:55:04
# xls-slrcachecomboboxmenus-              2019-09-29 23:55:07
# xls-namedsheetviewspassivetest-         2019-09-29 23:55:07
# xls-chartfloatingobjectcontrolfallback- 2019-09-29 23:55:07
# xls-listfieldlookupoptimized-           2019-09-29 23:55:07
# xls-ideas-                              2019-09-29 23:55:07
# xls-helptabwhatsnewenabled-             2019-09-29 23:55:07
# xls-satoriforthirdpartiesenabled-       2019-08-20 12:40:10

# %% [markdown]
# ## Word

# %%
X_train, X_test, y_train, y_test = train_test_split(X['word'], y['word'], test_size=0.1)

# %%
rf = RandomForestClassifier(random_state=0)
param_grid = { 
    'n_estimators': [50, 100, 250, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [2,5,10,None],
    'oob_score': [True,False]}

CV_rfc = GridSearchCV(estimator=rf, n_jobs=-1, param_grid=param_grid, verbose=10, scoring='neg_log_loss',cv= 5)
CV_rfc.fit(X_train, y_train)
print(CV_rfc.best_params_, CV_rfc.best_score_)

print(RandomForestClassifier(random_state=0).fit(X_train,
                                           y_train).score(X_test,y_test))
rfc = RandomForestClassifier(random_state = 0, n_estimators = 500,
                      max_depth=5,oob_score=True)

rfc.fit(X_train,y_train)
rfc.score(X_test,y_test)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   19.7s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   24.9s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   50.4s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   59.3s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed: 19.2min
# [Parallel(n_jobs=-1)]: Done 480 out of 480 | elapsed: 20.1min finished
# {'max_depth': 5, 'max_features': 'auto', 'n_estimators': 100, 'oob_score': True} -0.5600213224138181
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.6994848311390955
# 0.7584430452203778

# %%
learners = rfc.feature_importances_.argsort()[::-1]
features = pd.DataFrame(X_train.columns[learners], rfc.feature_importances_[learners])
features = features[features.index>0.025]
features
# Out:
#                                                  FlightPair
# 0.106023                           wac-wordideasexperience-
# 0.069156        wac-wordcopypasteparagraphcharacterstyleid-
# 0.049805                        wac-wordhometabownoverflow-
# 0.045594                                     wac-wordideas-
# 0.044594                wac-wordconditionalinsideborderfix-
# 0.039080                            wac-wordappnamerebrand-
# 0.036940       wac-wordeditortableofcontentcreateanddelete-
# 0.035142    wac-wordbrowsershowserrorwhenwaitingonlongboot-
# 0.030356  wac-wordinteractiveperfoverlaycontrolrenderopt...
# 0.029938     wac-wordallowcontenteditabledragoutsidewindow-
# 0.027572                      wac-fetchkeepaliveonshutdown-

# %%
print(LogisticRegression().fit(X_train,y_train).score(X_test,y_test), ' -->...')

for i in [1,2,3,4,5,10,15,20,25,50,75,100]:
    print('Score with Top ',i,' Features:')
    logit = LogisticRegression(solver='liblinear')

    rfe = RFE(logit,i)
    rfe = rfe.fit(X_train,y_train.values.ravel())

    rfe.support_
    rfe.ranking_

    #identified columns Recursive Feature Elimination
    idc_rfe = pd.DataFrame({"rfe_support" :rfe.support_,
                           "columns" : [i for i in X_train.columns],
                           "ranking" : rfe.ranking_,
                          })
    cols = idc_rfe[idc_rfe["rfe_support"] == True]["columns"].tolist()


    #separating train and test data
    train_rfe_X = X_train[cols]
    train_rfe_y = y_train.copy()

    test_rfe_X = X_test[cols]
    test_rfe_y = y_test.copy()


    logit_rfe = LogisticRegression(class_weight=None, dual=False, fit_intercept=True,
              intercept_scaling=1, max_iter=100, #n_jobs=4,
              penalty='l2', random_state=None, solver='liblinear', #tol=0.0001,
              verbose=0, warm_start=False)

    logit_rfe.fit(train_rfe_X, train_rfe_y)
    print(logit_rfe.score(test_rfe_X,test_rfe_y))
# Out:
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.7561534058385804  -->...
# Score with Top  1  Features:
# 0.7561534058385804
# Score with Top  2  Features:
# 0.7561534058385804
# Score with Top  3  Features:
# 0.7561534058385804
# Score with Top  4  Features:
# 0.7561534058385804
# Score with Top  5  Features:
# 0.7561534058385804
# Score with Top  10  Features:
# 0.7561534058385804
# Score with Top  15  Features:
# 0.7561534058385804
# Score with Top  20  Features:
# 0.7561534058385804
# Score with Top  25  Features:
# 0.7561534058385804
# Score with Top  50  Features:
# 0.7555809959931311
# Score with Top  75  Features:
# 0.7555809959931311
# Score with Top  100  Features:
# 0.7561534058385804

# %%
logit = LogisticRegression(solver='liblinear')

rfe = RFE(logit,10)
rfe = rfe.fit(X_train,y_train.values.ravel())

rfe.ranking_

#identified columns Recursive Feature Elimination
idc_rfe = pd.DataFrame({"rfe_support" :rfe.support_,
                       "columns" : [i for i in X_train.columns],
                       "ranking" : rfe.ranking_,
                      })

# %%
cols = idc_rfe[idc_rfe["rfe_support"] == True]["columns"].tolist()

# %%
cols.extend(features.FlightPair.values.tolist())

# %%
cols
# Out:
# ['wac-wordclearformattingtrackchanges-',
#  'wac-wordcopypasteparagraphcharacterstyleid-',
#  'wac-wordeditorinlinetabs-',
#  'wac-wordeditorinlinetabsfeaturecomposition-',
#  'wac-wordeditorserviceverificationloopab-',
#  'wac-wordhandlemixedlistparagraphmultiselect-',
#  'wac-wordinteractiveperflimitproofingresume-',
#  'wac-wordinteractiveperfscrollimprovement-',
#  'wac-wordlogtasksdetailsfromcpumeter-',
#  'wac-wordmergedparagraphwordidmappingimprovements-',
#  'wac-wordideasexperience-',
#  'wac-wordcopypasteparagraphcharacterstyleid-',
#  'wac-wordhometabownoverflow-',
#  'wac-wordideas-',
#  'wac-wordconditionalinsideborderfix-',
#  'wac-wordappnamerebrand-',
#  'wac-wordeditortableofcontentcreateanddelete-',
#  'wac-wordbrowsershowserrorwhenwaitingonlongboot-',
#  'wac-wordinteractiveperfoverlaycontrolrenderoptimization-',
#  'wac-wordallowcontenteditabledragoutsidewindow-',
#  'wac-fetchkeepaliveonshutdown-']

# %%
cols = list(set(cols))

logit = sm.Logit(y['word'],X['word'].loc[:,cols])
flogit = logit.fit()
print(flogit.summary())
coefficients = flogit.summary2().tables[1]
coefficients = coefficients[coefficients['P>|z|']<0.1]
coefficients['Odds Ratio']=np.exp(coefficients['Coef.'])
coefficients['O.R.LB']=np.exp(coefficients['[0.025'])
coefficients['O.R.UB']=np.exp(coefficients['0.975]'])
coefficients.join(flight_durations)
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.604487
#          Iterations: 35
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    NPS   No. Observations:                17466
# Model:                          Logit   Df Residuals:                    17446
# Method:                           MLE   Df Model:                           19
# Date:                Thu, 17 Oct 2019   Pseudo R-squ.:                -0.07430
# Time:                        15:48:12   Log-Likelihood:                -10558.
# converged:                      False   LL-Null:                       -9827.8
#                                         LLR p-value:                     1.000
# ============================================================================================================================
#                                                                coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# wac-wordclearformattingtrackchanges-                         0.5986      1.054      0.568      0.570      -1.467       2.664
# wac-wordhandlemixedlistparagraphmultiselect-                 0.7166      0.052     13.809      0.000       0.615       0.818
# wac-wordeditorinlinetabs-                                    0.6400      0.546      1.173      0.241      -0.430       1.710
# wac-wordinteractiveperfoverlaycontrolrenderoptimization-     0.7671      0.069     11.054      0.000       0.631       0.903
# wac-wordmergedparagraphwordidmappingimprovements-            0.8880      0.143      6.220      0.000       0.608       1.168
# wac-wordinteractiveperflimitproofingresume-                  0.1079      0.243      0.444      0.657      -0.368       0.584
# wac-wordideas-                                               0.0129      0.134      0.096      0.923      -0.249       0.275
# wac-wordinteractiveperfscrollimprovement-                    0.1692      0.289      0.586      0.558      -0.396       0.735
# wac-wordlogtasksdetailsfromcpumeter-                         0.2369      0.201      1.177      0.239      -0.158       0.631
# wac-wordcopypasteparagraphcharacterstyleid-                  1.8109      1.033      1.753      0.080      -0.214       3.835
# wac-wordconditionalinsideborderfix-                          0.2226      0.100      2.229      0.026       0.027       0.418
# wac-wordbrowsershowserrorwhenwaitingonlongboot-              0.5323      0.163      3.271      0.001       0.213       0.851
# wac-fetchkeepaliveonshutdown-                                0.8091      0.038     21.550      0.000       0.735       0.883
# wac-wordhometabownoverflow-                                  0.1103      0.114      0.968      0.333      -0.113       0.333
# wac-wordideasexperience-                                    15.3625   3015.417      0.005      0.996   -5894.745    5925.470
# wac-wordallowcontenteditabledragoutsidewindow-               0.2217      0.080      2.783      0.005       0.066       0.378
# wac-wordeditortableofcontentcreateanddelete-                 0.6148      0.206      2.982      0.003       0.211       1.019
# wac-wordappnamerebrand-                                     -0.0069      0.115     -0.060      0.952      -0.232       0.218
# wac-wordeditorserviceverificationloopab-                    -0.2906      0.116     -2.512      0.012      -0.517      -0.064
# wac-wordeditorinlinetabsfeaturecomposition-                  0.3018      0.549      0.550      0.582      -0.774       1.377
# ============================================================================================================================
# C:\Users\v-Jaand\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#                                                        Coef.  Std.Err.  \
# wac-wordhandlemixedlistparagraphmultiselect-        0.716570  0.051891
# wac-wordinteractiveperfoverlaycontrolrenderopti...  0.767058  0.069394
# wac-wordmergedparagraphwordidmappingimprovements-   0.887977  0.142771
# wac-wordcopypasteparagraphcharacterstyleid-         1.810919  1.032954
# wac-wordconditionalinsideborderfix-                 0.222581  0.099852
# wac-wordbrowsershowserrorwhenwaitingonlongboot-     0.532331  0.162742
# wac-fetchkeepaliveonshutdown-                       0.809075  0.037544
# wac-wordallowcontenteditabledragoutsidewindow-      0.221656  0.079655
# wac-wordeditortableofcontentcreateanddelete-        0.614802  0.206169
# wac-wordeditorserviceverificationloopab-           -0.290557  0.115649
#
#                                                             z          P>|z|  \
# wac-wordhandlemixedlistparagraphmultiselect-        13.809032   2.248326e-43
# wac-wordinteractiveperfoverlaycontrolrenderopti...  11.053717   2.103228e-28
# wac-wordmergedparagraphwordidmappingimprovements-    6.219600   4.984250e-10
# wac-wordcopypasteparagraphcharacterstyleid-          1.753146   7.957701e-02
# wac-wordconditionalinsideborderfix-                  2.229111   2.580652e-02
# wac-wordbrowsershowserrorwhenwaitingonlongboot-      3.271017   1.071614e-03
# wac-fetchkeepaliveonshutdown-                       21.549834  5.313769e-103
# wac-wordallowcontenteditabledragoutsidewindow-       2.782713   5.390648e-03
# wac-wordeditortableofcontentcreateanddelete-         2.982027   2.863464e-03
# wac-wordeditorserviceverificationloopab-            -2.512409   1.199101e-02
#
#                                                       [0.025    0.975]  \
# wac-wordhandlemixedlistparagraphmultiselect-        0.614865  0.818275
# wac-wordinteractiveperfoverlaycontrolrenderopti...  0.631049  0.903067
# wac-wordmergedparagraphwordidmappingimprovements-   0.608152  1.167803
# wac-wordcopypasteparagraphcharacterstyleid-        -0.213634  3.835472
# wac-wordconditionalinsideborderfix-                 0.026875  0.418286
# wac-wordbrowsershowserrorwhenwaitingonlongboot-     0.213363  0.851298
# wac-fetchkeepaliveonshutdown-                       0.735489  0.882660
# wac-wordallowcontenteditabledragoutsidewindow-      0.065536  0.377777
# wac-wordeditortableofcontentcreateanddelete-        0.210718  1.018887
# wac-wordeditorserviceverificationloopab-           -0.517225 -0.063890
#
#                                                     Odds Ratio    O.R.LB  \
# wac-wordhandlemixedlistparagraphmultiselect-          2.047398  1.849406
# wac-wordinteractiveperfoverlaycontrolrenderopti...    2.153421  1.879581
# wac-wordmergedparagraphwordidmappingimprovements-     2.430209  1.837033
# wac-wordcopypasteparagraphcharacterstyleid-           6.116067  0.807644
# wac-wordconditionalinsideborderfix-                   1.249296  1.027239
# wac-wordbrowsershowserrorwhenwaitingonlongboot-       1.702896  1.237834
# wac-fetchkeepaliveonshutdown-                         2.245829  2.086502
# wac-wordallowcontenteditabledragoutsidewindow-        1.248142  1.067731
# wac-wordeditortableofcontentcreateanddelete-          1.849291  1.234564
# wac-wordeditorserviceverificationloopab-              0.747847  0.596172
#
#                                                        O.R.UB  \
# wac-wordhandlemixedlistparagraphmultiselect-         2.266587
# wac-wordinteractiveperfoverlaycontrolrenderopti...   2.467158
# wac-wordmergedparagraphwordidmappingimprovements-    3.214922
# wac-wordcopypasteparagraphcharacterstyleid-         46.315296
# wac-wordconditionalinsideborderfix-                  1.519356
# wac-wordbrowsershowserrorwhenwaitingonlongboot-      2.342686
# wac-fetchkeepaliveonshutdown-                        2.417322
# wac-wordallowcontenteditabledragoutsidewindow-       1.459038
# wac-wordeditortableofcontentcreateanddelete-         2.770109
# wac-wordeditorserviceverificationloopab-             0.938109
#
#                                                            FlightStart  \
# wac-wordhandlemixedlistparagraphmultiselect-       2019-06-04 16:49:49
# wac-wordinteractiveperfoverlaycontrolrenderopti... 2019-06-03 22:44:21
# wac-wordmergedparagraphwordidmappingimprovements-  2019-05-16 00:39:21
# wac-wordcopypasteparagraphcharacterstyleid-        2019-09-27 20:14:10
# wac-wordconditionalinsideborderfix-                2019-05-16 00:19:19
# wac-wordbrowsershowserrorwhenwaitingonlongboot-    2019-05-16 07:20:28
# wac-fetchkeepaliveonshutdown-                      2019-07-12 19:30:22
# wac-wordallowcontenteditabledragoutsidewindow-     2019-05-25 00:39:04
# wac-wordeditortableofcontentcreateanddelete-       2019-05-16 00:19:19
# wac-wordeditorserviceverificationloopab-           2019-05-16 00:19:19
#
#                                                              FlightEnd
# wac-wordhandlemixedlistparagraphmultiselect-       2019-09-15 10:19:26
# wac-wordinteractiveperfoverlaycontrolrenderopti... 2019-07-08 19:14:13
# wac-wordmergedparagraphwordidmappingimprovements-  2019-06-12 02:39:11
# wac-wordcopypasteparagraphcharacterstyleid-        2019-09-29 22:29:05
# wac-wordconditionalinsideborderfix-                2019-07-11 00:00:07
# wac-wordbrowsershowserrorwhenwaitingonlongboot-    2019-06-11 22:44:05
# wac-fetchkeepaliveonshutdown-                      2019-09-17 19:50:21
# wac-wordallowcontenteditabledragoutsidewindow-     2019-08-08 21:10:18
# wac-wordeditortableofcontentcreateanddelete-       2019-05-20 21:14:13
# wac-wordeditorserviceverificationloopab-           2019-09-18 08:25:50

# %% [markdown]
# ## PowerPoint

# %%
print('PowerPoint AllUp MODEL')
logit = sm.Logit(y['pp'],X['pp'])
flogit = logit.fit()
print(flogit.summary())
coefficients = flogit.summary2().tables[1]
coefficients = coefficients[coefficients['P>|z|']<0.1]
coefficients['Odds Ratio']=np.exp(coefficients['Coef.'])
coefficients['O.R.LB']=np.exp(coefficients['[0.025'])
coefficients['O.R.UB']=np.exp(coefficients['0.975]'])
coefficients.join(flight_durations)
# Out:
# PowerPoint AllUp MODEL
# Optimization terminated successfully.
#          Current function value: 0.555416
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    NPS   No. Observations:                12963
# Model:                          Logit   Df Residuals:                    12949
# Method:                           MLE   Df Model:                           13
# Date:                Thu, 17 Oct 2019   Pseudo R-squ.:                -0.03091
# Time:                        14:56:02   Log-Likelihood:                -7199.9
# converged:                       True   LL-Null:                       -6984.0
#                                         LLR p-value:                     1.000
# ==============================================================================================================
#                                                  coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# ppt-designerdashboardtest-                     0.0821      0.055      1.494      0.135      -0.026       0.190
# ppt-formatpainterapplyremapped-                0.5306      0.048     11.139      0.000       0.437       0.624
# ppt-freemiumupsellheaderui-                    0.0064      0.147      0.044      0.965      -0.281       0.294
# ppt-helptabwhatsnewenabled-                    0.4756      0.097      4.903      0.000       0.285       0.666
# ppt-linktoslide-                               0.1647      0.112      1.466      0.143      -0.055       0.385
# ppt-newcommentdraftingapiisenabled-            0.1027      0.050      2.071      0.038       0.006       0.200
# ppt-newideas-                                  0.6476      0.036     17.925      0.000       0.577       0.718
# ppt-pasteslidekeepsourceformattingdefault-     0.0259      0.153      0.170      0.865      -0.274       0.325
# ppt-pptnewcommentbuttoninpane-                 0.7784      0.082      9.527      0.000       0.618       0.939
# ppt-pptsharedcommentsfluentui-                 0.5085      0.071      7.145      0.000       0.369       0.648
# ppt-sendshuttingdownbeaconrequests-            0.3631      0.241      1.503      0.133      -0.110       0.836
# ppt-slrcombinedoverflowmenus-                  0.8625      0.777      1.110      0.267      -0.660       2.385
# ppt-textformatpainter-                        -0.1885      0.088     -2.139      0.032      -0.361      -0.016
# ppt-wopitokenrefresh-                          0.4908      0.081      6.027      0.000       0.331       0.650
# ==============================================================================================================
#                                         Coef.  Std.Err.          z  \
# ppt-formatpainterapplyremapped-      0.530613  0.047638  11.138549
# ppt-helptabwhatsnewenabled-          0.475593  0.096992   4.903410
# ppt-newcommentdraftingapiisenabled-  0.102655  0.049557   2.071440
# ppt-newideas-                        0.647612  0.036129  17.924898
# ppt-pptnewcommentbuttoninpane-       0.778448  0.081709   9.527111
# ppt-pptsharedcommentsfluentui-       0.508543  0.071174   7.145039
# ppt-textformatpainter-              -0.188533  0.088142  -2.138963
# ppt-wopitokenrefresh-                0.490840  0.081444   6.026732
#
#                                             P>|z|    [0.025    0.975]  \
# ppt-formatpainterapplyremapped-      8.143528e-29  0.437245  0.623981
# ppt-helptabwhatsnewenabled-          9.418688e-07  0.285492  0.665695
# ppt-newcommentdraftingapiisenabled-  3.831765e-02  0.005524  0.199785
# ppt-newideas-                        7.538835e-72  0.576800  0.718424
# ppt-pptnewcommentbuttoninpane-       1.617205e-21  0.618302  0.938594
# ppt-pptsharedcommentsfluentui-       8.997051e-13  0.369044  0.648042
# ppt-textformatpainter-               3.243870e-02 -0.361288 -0.015777
# ppt-wopitokenrefresh-                1.673086e-09  0.331213  0.650467
#
#                                             FlightStart           FlightEnd
# ppt-formatpainterapplyremapped-     2019-07-04 02:04:08 2019-09-11 02:49:10
# ppt-helptabwhatsnewenabled-         2019-05-31 04:59:17 2019-09-29 22:44:04
# ppt-newcommentdraftingapiisenabled- 2019-05-03 18:29:05 2019-08-22 20:34:08
# ppt-newideas-                       2019-05-31 02:04:12 2019-09-29 23:54:06
# ppt-pptnewcommentbuttoninpane-      2019-05-01 00:04:11 2019-07-18 07:46:00
# ppt-pptsharedcommentsfluentui-      2019-08-21 14:34:14 2019-09-29 23:54:06
# ppt-textformatpainter-              2019-05-06 08:05:42 2019-07-11 09:54:30
# ppt-wopitokenrefresh-               2019-05-01 00:04:11 2019-09-29 22:44:04

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
rf = RandomForestClassifier(random_state=0)
param_grid = { 
    'n_estimators': [50, 100, 250, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [2,5,10,None],
    'oob_score': [True,False]}

CV_rfc = GridSearchCV(estimator=rf, n_jobs=-1, param_grid=param_grid, verbose=10, scoring='neg_log_loss',cv= 5)
CV_rfc.fit(X_train, y_train)
print(CV_rfc.best_params_, CV_rfc.best_score_)

# %% [markdown]
# ## Overall
#
# Flights that appear in each of the three apps

# %%
print('SATURATED MODEL')
logit = sm.Logit(y['all'],X['all'])
flogit = logit.fit()
print(flogit.summary())
coefficients = flogit.summary2().tables[1]
coefficients = coefficients[coefficients['P>|z|']<0.1]
coefficients['Odds Ratio']=np.exp(coefficients['Coef.'])
coefficients['O.R.LB']=np.exp(coefficients['[0.025'])
coefficients['O.R.UB']=np.exp(coefficients['0.975]'])
coefficients.join(flight_durations)
# Out:
# SATURATED MODEL
# Optimization terminated successfully.
#          Current function value: 0.572658
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                    NPS   No. Observations:                47053
# Model:                          Logit   Df Residuals:                    47028
# Method:                           MLE   Df Model:                           24
# Date:                Thu, 17 Oct 2019   Pseudo R-squ.:                -0.02428
# Time:                        14:56:09   Log-Likelihood:                -26945.
# converged:                       True   LL-Null:                       -26307.
#                                         LLR p-value:                     1.000
# ===============================================================================================================================
#                                                                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------
# docowner-canary-                                                0.3147      0.021     14.802      0.000       0.273       0.356
# wac-wordclearformattingtrackchanges-                            0.0296      0.328      0.090      0.928      -0.613       0.672
# wac-box4directprinthidesensitiveparameters-                     0.0914      0.065      1.409      0.159      -0.036       0.219
# xls-overridebrowsershortcuts-                                   0.4006      0.043      9.391      0.000       0.317       0.484
# wac-wordeditorcashdashisactivecoauth-                           0.5148      0.149      3.459      0.001       0.223       0.806
# wac-wordshowpasteoptionsincontextmenu-                          0.2504      0.061      4.111      0.000       0.131       0.370
# canary-docowner-                                                0.3916      0.044      8.996      0.000       0.306       0.477
# canary2-                                                        0.3201      0.019     16.501      0.000       0.282       0.358
# wac-worduseaadforfileupload-                                    0.3123      0.033      9.372      0.000       0.247       0.378
# wac-worddeprioritizerichtextcontentcontrolacetateforcoauth-    -0.0937      0.411     -0.228      0.819      -0.898       0.711
# wacdash-                                                        0.2948      0.020     14.677      0.000       0.255       0.334
# wac-wordsdxpreloadpackagelist-                                  0.3321      0.053      6.262      0.000       0.228       0.436
# firstrelease-                                                   0.3081      0.035      8.762      0.000       0.239       0.377
# wac-wordpreserveverbonredirect-                                 0.2399      0.024     10.063      0.000       0.193       0.287
# wac-wordwordoauthtestappmsatokenretrieval-                      0.8219      0.191      4.310      0.000       0.448       1.196
# xls-removescrolltofirstandlastsheettabnavbuttons-               0.1244      0.185      0.673      0.501      -0.238       0.487
# docowneridtestaa-                                               0.1748      0.062      2.808      0.005       0.053       0.297
# wac-owaunifiedapp-                                              0.2346      0.035      6.682      0.000       0.166       0.303
# useridtestaa-                                                   0.1390      0.062      2.246      0.025       0.018       0.260
# canary-                                                         0.3193      0.019     16.511      0.000       0.281       0.357
# wac-mergemissingeopfix-                                         0.0249      0.109      0.230      0.818      -0.188       0.238
# xls-customsortforallrangetypes-                                 0.2603      0.054      4.785      0.000       0.154       0.367
# wac-minimizeintelligentplaceholderwork-                         0.3372      0.133      2.542      0.011       0.077       0.597
# wac-wordwordoauthtestappaadtokenretrieval-                      0.2716      0.030      9.010      0.000       0.213       0.331
# wac-wordkeepmaxlastknownheight-                                 0.1748      0.058      2.989      0.003       0.060       0.289
# ===============================================================================================================================
#                                                Coef.  Std.Err.          z  \
# docowner-canary-                            0.314681  0.021259  14.802250
# xls-overridebrowsershortcuts-               0.400569  0.042653   9.391334
# wac-wordeditorcashdashisactivecoauth-       0.514753  0.148820   3.458908
# wac-wordshowpasteoptionsincontextmenu-      0.250356  0.060892   4.111488
# canary-docowner-                            0.391644  0.043537   8.995638
# canary2-                                    0.320066  0.019397  16.500886
# wac-worduseaadforfileupload-                0.312258  0.033318   9.372120
# wacdash-                                    0.294835  0.020089  14.676704
# wac-wordsdxpreloadpackagelist-              0.332120  0.053040   6.261674
# firstrelease-                               0.308134  0.035166   8.762366
# wac-wordpreserveverbonredirect-             0.239915  0.023841  10.063125
# wac-wordwordoauthtestappmsatokenretrieval-  0.821939  0.190725   4.309546
# docowneridtestaa-                           0.174848  0.062278   2.807558
# wac-owaunifiedapp-                          0.234615  0.035112   6.681834
# useridtestaa-                               0.138959  0.061857   2.246460
# canary-                                     0.319302  0.019339  16.510739
# xls-customsortforallrangetypes-             0.260263  0.054393   4.784840
# wac-minimizeintelligentplaceholderwork-     0.337191  0.132669   2.541598
# wac-wordwordoauthtestappaadtokenretrieval-  0.271609  0.030145   9.010120
# wac-wordkeepmaxlastknownheight-             0.174816  0.058480   2.989343
#
#                                                    P>|z|    [0.025    0.975]  \
# docowner-canary-                            1.416640e-49  0.273014  0.356348
# xls-overridebrowsershortcuts-               5.924493e-21  0.316970  0.484167
# wac-wordeditorcashdashisactivecoauth-       5.423706e-04  0.223072  0.806434
# wac-wordshowpasteoptionsincontextmenu-      3.931180e-05  0.131010  0.369702
# canary-docowner-                            2.348633e-19  0.306313  0.476975
# canary2-                                    3.615509e-61  0.282049  0.358083
# wac-worduseaadforfileupload-                7.109002e-21  0.246956  0.377560
# wacdash-                                    9.090234e-49  0.255462  0.334208
# wac-wordsdxpreloadpackagelist-              3.808669e-10  0.228163  0.436077
# firstrelease-                               1.911936e-18  0.239211  0.377058
# wac-wordpreserveverbonredirect-             8.040470e-24  0.193188  0.286643
# wac-wordwordoauthtestappmsatokenretrieval-  1.635897e-05  0.448125  1.195754
# docowneridtestaa-                           4.991865e-03  0.052786  0.296910
# wac-owaunifiedapp-                          2.359709e-11  0.165796  0.303434
# useridtestaa-                               2.467458e-02  0.017722  0.260196
# canary-                                     3.071007e-61  0.281398  0.357206
# xls-customsortforallrangetypes-             1.711234e-06  0.153654  0.366871
# wac-minimizeintelligentplaceholderwork-     1.103470e-02  0.077165  0.597218
# wac-wordwordoauthtestappaadtokenretrieval-  2.058310e-19  0.212526  0.330692
# wac-wordkeepmaxlastknownheight-             2.795781e-03  0.060198  0.289433
#
#                                                    FlightStart  \
# docowner-canary-                           2019-05-01 00:04:11
# xls-overridebrowsershortcuts-              2019-08-25 10:09:31
# wac-wordeditorcashdashisactivecoauth-      2019-09-24 18:20:12
# wac-wordshowpasteoptionsincontextmenu-     2019-07-08 18:14:05
# canary-docowner-                           2019-09-18 18:19:11
# canary2-                                   2019-05-01 00:04:11
# wac-worduseaadforfileupload-               2019-07-10 18:59:06
# wacdash-                                   2019-05-01 00:04:11
# wac-wordsdxpreloadpackagelist-             2019-09-09 18:09:56
# firstrelease-                              2019-05-01 00:04:11
# wac-wordpreserveverbonredirect-            2019-05-01 00:04:11
# wac-wordwordoauthtestappmsatokenretrieval- 2019-09-03 18:54:16
# docowneridtestaa-                          2019-05-01 00:04:11
# wac-owaunifiedapp-                         2019-07-29 18:44:06
# useridtestaa-                              2019-05-01 00:04:11
# canary-                                    2019-05-01 00:04:11
# xls-customsortforallrangetypes-            2019-05-28 19:44:40
# wac-minimizeintelligentplaceholderwork-    2019-09-03 23:49:07
# wac-wordwordoauthtestappaadtokenretrieval- 2019-06-12 12:04:04
# wac-wordkeepmaxlastknownheight-            2019-09-19 18:34:06
#
#                                                      FlightEnd
# docowner-canary-                           2019-09-17 17:10:09
# xls-overridebrowsershortcuts-              2019-09-29 23:55:04
# wac-wordeditorcashdashisactivecoauth-      2019-09-29 23:50:05
# wac-wordshowpasteoptionsincontextmenu-     2019-09-29 23:50:05
# canary-docowner-                           2019-09-29 23:55:07
# canary2-                                   2019-09-29 23:55:07
# wac-worduseaadforfileupload-               2019-09-10 20:10:08
# wacdash-                                   2019-09-29 23:55:07
# wac-wordsdxpreloadpackagelist-             2019-09-29 23:55:07
# firstrelease-                              2019-09-29 23:55:07
# wac-wordpreserveverbonredirect-            2019-08-12 15:19:05
# wac-wordwordoauthtestappmsatokenretrieval- 2019-09-24 12:29:56
# docowneridtestaa-                          2019-07-15 18:10:07
# wac-owaunifiedapp-                         2019-09-29 23:54:06
# useridtestaa-                              2019-07-15 18:10:07
# canary-                                    2019-09-29 23:55:07
# xls-customsortforallrangetypes-            2019-08-12 15:19:05
# wac-minimizeintelligentplaceholderwork-    2019-09-27 11:34:06
# wac-wordwordoauthtestappaadtokenretrieval- 2019-09-24 18:00:06
# wac-wordkeepmaxlastknownheight-            2019-09-29 23:55:07
